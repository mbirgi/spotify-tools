# %%
import matplotlib.pyplot as plt
import pandas as pd

import spotify
import utils

sp = spotify.login(scope='playlist-modify-private')
user = sp.current_user()
username = user['id']
displayName = user['display_name']
displayName
# Out:
# Enter the URL you were redirected to:  https://localhost:8080/?code=AQBn6ykNAkEdvGOp4zz0zPV-cNp7CIav7fo-rIuWgM9fRn1BFlbzhUrZlsG4O8Dmp7aKkoWRwWwm1gptkKPCQEO99kPlH-TOZzi0gLs6cP0CJ9EPUdCmsJ-6ynwHv8La3QewkEmtFE8XQezarGie1nh8IP3ioMjltMXdvEXfjmUBwVQ6Z-ulcSUxeJnz_7kdLL5nwQ
# 'Mehmet Birgi'

# %%
# get all my playlists 
response = sp.current_user_playlists()
all_playlists = response['items']
while response['next']:
    response = sp.next(response)
    all_playlists.extend(response['items'])
len(all_playlists)
# Out:
# 37

# %%
all_playlists
# Out:
# [{'collaborative': False,
#   'description': 'Mostly down- and midtempo, jazzy stuff',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/7taG2mm7i5ng9FTSYGXXgG'},
#   'href': 'https://api.spotify.com/v1/playlists/7taG2mm7i5ng9FTSYGXXgG',
#   'id': '7taG2mm7i5ng9FTSYGXXgG',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b27303c2a908c93614d7eac0032fab67616d0000b2736ae6067bd94d9f738a917697ab67616d0000b273c285bb6d435e94ccd5940c5aab67616d0000b273f9a0bce0e33ae3e356db0282',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b27303c2a908c93614d7eac0032fab67616d0000b2736ae6067bd94d9f738a917697ab67616d0000b273c285bb6d435e94ccd5940c5aab67616d0000b273f9a0bce0e33ae3e356db0282',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b27303c2a908c93614d7eac0032fab67616d0000b2736ae6067bd94d9f738a917697ab67616d0000b273c285bb6d435e94ccd5940c5aab67616d0000b273f9a0bce0e33ae3e356db0282',
#     'width': 60}],
#   'name': 'Lounge',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'NjE5LDBhMmNkYzcxNjgzNWI1Yzg2YTM1NTIxNzliYWEyM2ZlZWZjYjUzYWI=',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/7taG2mm7i5ng9FTSYGXXgG/tracks',
#    'total': 566},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:7taG2mm7i5ng9FTSYGXXgG'},
#  {'collaborative': False,
#   'description': '',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/7wHVkQaQ45X055sUeU5Thx'},
#   'href': 'https://api.spotify.com/v1/playlists/7wHVkQaQ45X055sUeU5Thx',
#   'id': '7wHVkQaQ45X055sUeU5Thx',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b2733dfb7a693acec95ad2314b61ab67616d0000b27384d728ce13d5a2062e2d6487ab67616d0000b273a7b878d9cb37c37e219e8860ab67616d0000b273bb6babd3fa287a67c32ed12a',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b2733dfb7a693acec95ad2314b61ab67616d0000b27384d728ce13d5a2062e2d6487ab67616d0000b273a7b878d9cb37c37e219e8860ab67616d0000b273bb6babd3fa287a67c32ed12a',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b2733dfb7a693acec95ad2314b61ab67616d0000b27384d728ce13d5a2062e2d6487ab67616d0000b273a7b878d9cb37c37e219e8860ab67616d0000b273bb6babd3fa287a67c32ed12a',
#     'width': 60}],
#   'name': 'Straight Ahead Jazz',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'MjcyLGVmY2Y5NzY2NWUyYzYyOGVhMjQ0YjBlMDk0Y2Y1NTY4OWI2OTQ3OTA=',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/7wHVkQaQ45X055sUeU5Thx/tracks',
#    'total': 265},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:7wHVkQaQ45X055sUeU5Thx'},
#  {'collaborative': False,
#   'description': 'Handpicked, relaxed, low and mid-tempo classic and contemporary jazz',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/6u5RL72VpPaJfeLksVLE2Q'},
#   'href': 'https://api.spotify.com/v1/playlists/6u5RL72VpPaJfeLksVLE2Q',
#   'id': '6u5RL72VpPaJfeLksVLE2Q',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b273028ede8b512bcdad84b887e1ab67616d0000b2737ab89c25093ea3787b1995b4ab67616d0000b273b4242c51f21e10d593e17b10ab67616d0000b273e1e375708bba16dc6ab4b6e8',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b273028ede8b512bcdad84b887e1ab67616d0000b2737ab89c25093ea3787b1995b4ab67616d0000b273b4242c51f21e10d593e17b10ab67616d0000b273e1e375708bba16dc6ab4b6e8',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b273028ede8b512bcdad84b887e1ab67616d0000b2737ab89c25093ea3787b1995b4ab67616d0000b273b4242c51f21e10d593e17b10ab67616d0000b273e1e375708bba16dc6ab4b6e8',
#     'width': 60}],
#   'name': 'Mellow Jazz',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'NTI5LGUzZWUyN2VlNjk0Y2ZhM2NmZjI5YmVmOTlmNDQzZThjNGQyNjc0NTE=',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/6u5RL72VpPaJfeLksVLE2Q/tracks',
#    'total': 833},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:6u5RL72VpPaJfeLksVLE2Q'},
#  {'collaborative': False,
#   'description': '',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/01PEgqXn5ZhC8z9a7HpVmG'},
#   'href': 'https://api.spotify.com/v1/playlists/01PEgqXn5ZhC8z9a7HpVmG',
#   'id': '01PEgqXn5ZhC8z9a7HpVmG',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b2735180048d1ffd151c6947822bab67616d0000b273b5c9eb3bb09b23ac2e515f9fab67616d0000b273bdda6a4e9793de67f7598c91ab67616d0000b273d93e86fa97b4c91297a85699',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b2735180048d1ffd151c6947822bab67616d0000b273b5c9eb3bb09b23ac2e515f9fab67616d0000b273bdda6a4e9793de67f7598c91ab67616d0000b273d93e86fa97b4c91297a85699',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b2735180048d1ffd151c6947822bab67616d0000b273b5c9eb3bb09b23ac2e515f9fab67616d0000b273bdda6a4e9793de67f7598c91ab67616d0000b273d93e86fa97b4c91297a85699',
#     'width': 60}],
#   'name': 'Groovy Jazz',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'MzkyLGUyYjI4YzA3YWQzNjg3ZTczOWEyMDY2ZjQ4NjNhZDVlZTBjZjlhNDM=',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/01PEgqXn5ZhC8z9a7HpVmG/tracks',
#    'total': 299},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:01PEgqXn5ZhC8z9a7HpVmG'},
#  {'collaborative': False,
#   'description': 'Ska, rocksteady, roots reggae and dancehall favourites',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/7JYdgqlBBhiCqjpx2pVKwf'},
#   'href': 'https://api.spotify.com/v1/playlists/7JYdgqlBBhiCqjpx2pVKwf',
#   'id': '7JYdgqlBBhiCqjpx2pVKwf',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706c0000bebbb040f2c0c7bfe3c7c673428e',
#     'width': None}],
#   'name': 'Reggae',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'MTE5NCwzM2NmMWUxNjZiYmYzNjEzMjQ3ZThkNGY1Y2JlZWExODFkYzQzNzBh',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/7JYdgqlBBhiCqjpx2pVKwf/tracks',
#    'total': 551},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:7JYdgqlBBhiCqjpx2pVKwf'},
#  {'collaborative': False,
#   'description': 'Groovy Funk, Soul and R&amp;B stuff',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/0vay9gW8AcsmEycNCh8pnz'},
#   'href': 'https://api.spotify.com/v1/playlists/0vay9gW8AcsmEycNCh8pnz',
#   'id': '0vay9gW8AcsmEycNCh8pnz',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706c0000bebbf85c552954848d80aa3e9b5e',
#     'width': None}],
#   'name': 'Groovy Stuff',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'MzI5LDYxZGVhODU2MjI4MDMyMjY4Njc3ZWQ5MWU1N2FmYmZkY2I4NmEwOGI=',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/0vay9gW8AcsmEycNCh8pnz/tracks',
#    'total': 371},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:0vay9gW8AcsmEycNCh8pnz'},
#  {'collaborative': False,
#   'description': 'Uplifting evergreens',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/2MzQi9D9OtFuUsuOS8lwtS'},
#   'href': 'https://api.spotify.com/v1/playlists/2MzQi9D9OtFuUsuOS8lwtS',
#   'id': '2MzQi9D9OtFuUsuOS8lwtS',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b2736f9dd97171a383e798190ba1ab67616d0000b2738460b41f0ffb36c0c212119fab67616d0000b273b59ff6e6cfd38df73bd1ca10ab67616d0000b273c791c7423d7b3b9f02fb093a',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b2736f9dd97171a383e798190ba1ab67616d0000b2738460b41f0ffb36c0c212119fab67616d0000b273b59ff6e6cfd38df73bd1ca10ab67616d0000b273c791c7423d7b3b9f02fb093a',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b2736f9dd97171a383e798190ba1ab67616d0000b2738460b41f0ffb36c0c212119fab67616d0000b273b59ff6e6cfd38df73bd1ca10ab67616d0000b273c791c7423d7b3b9f02fb093a',
#     'width': 60}],
#   'name': 'Power Songs',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'NTAwLDBlMGRjOGJmMThiZWRmYWNkN2MzZjVkYTliYjBlY2ViMjBlY2M3ZTk=',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/2MzQi9D9OtFuUsuOS8lwtS/tracks',
#    'total': 588},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:2MzQi9D9OtFuUsuOS8lwtS'},
#  {'collaborative': False,
#   'description': 'Big playlist for shuffling, diverse genres',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/2YMU8rioLryuhi4QhtXIAy'},
#   'href': 'https://api.spotify.com/v1/playlists/2YMU8rioLryuhi4QhtXIAy',
#   'id': '2YMU8rioLryuhi4QhtXIAy',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706c0000bebb3e32d8c1441e3fbc06bee528',
#     'width': None}],
#   'name': 'Eclectic Mix',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'ODksNmM4ZjMwNjk1YmE2NmQ5MGNjNjA4MGJiNDMxMDA3ZWYzMjY1ZmFkNg==',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/2YMU8rioLryuhi4QhtXIAy/tracks',
#    'total': 7101},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:2YMU8rioLryuhi4QhtXIAy'},
#  {'collaborative': False,
#   'description': 'Trip-Hop song highlights from allmusic.com',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/5hjUKe8JJQQC521mSCZqzX'},
#   'href': 'https://api.spotify.com/v1/playlists/5hjUKe8JJQQC521mSCZqzX',
#   'id': '5hjUKe8JJQQC521mSCZqzX',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b273032e395e4a79caf92cc924c9ab67616d0000b273768d171a47a3adae90c7c48aab67616d0000b273b129ba321c1903f9990a2612ab67616d0000b273dc20397b139223620af148f6',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b273032e395e4a79caf92cc924c9ab67616d0000b273768d171a47a3adae90c7c48aab67616d0000b273b129ba321c1903f9990a2612ab67616d0000b273dc20397b139223620af148f6',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b273032e395e4a79caf92cc924c9ab67616d0000b273768d171a47a3adae90c7c48aab67616d0000b273b129ba321c1903f9990a2612ab67616d0000b273dc20397b139223620af148f6',
#     'width': 60}],
#   'name': 'Trip-Hop',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'NSwxMWRkMDEwZDg0MGYxYWFlNmM1NjY1MmQxYTg4ZTNlMTc2NGU0MmM0',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/5hjUKe8JJQQC521mSCZqzX/tracks',
#    'total': 39},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:5hjUKe8JJQQC521mSCZqzX'},
#  {'collaborative': False,
#   'description': 'Clubjazz song highlights from allmusic.com',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/5DzWiA5uNMsMevFSCdcfgp'},
#   'href': 'https://api.spotify.com/v1/playlists/5DzWiA5uNMsMevFSCdcfgp',
#   'id': '5DzWiA5uNMsMevFSCdcfgp',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b2731f21360c317e09449797e684ab67616d0000b273b177165432854f9c77369c52ab67616d0000b273cf07f83667ece744151a62b1ab67616d0000b273dd2d9468d033581c425eee83',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b2731f21360c317e09449797e684ab67616d0000b273b177165432854f9c77369c52ab67616d0000b273cf07f83667ece744151a62b1ab67616d0000b273dd2d9468d033581c425eee83',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b2731f21360c317e09449797e684ab67616d0000b273b177165432854f9c77369c52ab67616d0000b273cf07f83667ece744151a62b1ab67616d0000b273dd2d9468d033581c425eee83',
#     'width': 60}],
#   'name': 'Clubjazz',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'NSw2NjY4ZGQ2MzEyMDM4MzZiZjc2YzI4NzNhYWMxYWM3NTA4NTQ5M2Yx',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/5DzWiA5uNMsMevFSCdcfgp/tracks',
#    'total': 36},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:5DzWiA5uNMsMevFSCdcfgp'},
#  {'collaborative': False,
#   'description': 'Funky Beats song highlights from allmusic.com',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/4gbxlR9bGUvaRdUZNKhacP'},
#   'href': 'https://api.spotify.com/v1/playlists/4gbxlR9bGUvaRdUZNKhacP',
#   'id': '4gbxlR9bGUvaRdUZNKhacP',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b2730fde49678102915a0fc93d22ab67616d0000b2731c23f258378f32d8d63dc150ab67616d0000b273befecaa2c30a3302c88cbe88ab67616d0000b273e7da90a707e3afb0159ce8b9',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b2730fde49678102915a0fc93d22ab67616d0000b2731c23f258378f32d8d63dc150ab67616d0000b273befecaa2c30a3302c88cbe88ab67616d0000b273e7da90a707e3afb0159ce8b9',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b2730fde49678102915a0fc93d22ab67616d0000b2731c23f258378f32d8d63dc150ab67616d0000b273befecaa2c30a3302c88cbe88ab67616d0000b273e7da90a707e3afb0159ce8b9',
#     'width': 60}],
#   'name': 'Funky Breaks',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'OCwyNDIxZTgzNWJjYzU1ZjM2OTcyNjI5YjM5NWUwMjQyM2MwODNkMGEw',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/4gbxlR9bGUvaRdUZNKhacP/tracks',
#    'total': 34},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:4gbxlR9bGUvaRdUZNKhacP'},
#  {'collaborative': False,
#   'description': 'Downbeat song highlights from allmusic.com',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/06BalMPv4H9hUvZa4PQQmA'},
#   'href': 'https://api.spotify.com/v1/playlists/06BalMPv4H9hUvZa4PQQmA',
#   'id': '06BalMPv4H9hUvZa4PQQmA',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b27324850f3eb04b5132b96df67aab67616d0000b27326f0ecc8eb1732574bc0e2b8ab67616d0000b273c22bda9298c19861bdf78a6eab67616d0000b273e2d276d02265cfd1adc0ee81',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b27324850f3eb04b5132b96df67aab67616d0000b27326f0ecc8eb1732574bc0e2b8ab67616d0000b273c22bda9298c19861bdf78a6eab67616d0000b273e2d276d02265cfd1adc0ee81',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b27324850f3eb04b5132b96df67aab67616d0000b27326f0ecc8eb1732574bc0e2b8ab67616d0000b273c22bda9298c19861bdf78a6eab67616d0000b273e2d276d02265cfd1adc0ee81',
#     'width': 60}],
#   'name': 'Downbeat',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'NSwzMTIxYjczNjUxNGVlZDM3ZmQyMGMyZTdiM2Y4ZGYyMmIxYTYxNTg1',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/06BalMPv4H9hUvZa4PQQmA/tracks',
#    'total': 37},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:06BalMPv4H9hUvZa4PQQmA'},
#  {'collaborative': False,
#   'description': 'Jazz-House song highlights from allmusic.com',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/5F1aBXHMHi1vEsjzhIR4ZM'},
#   'href': 'https://api.spotify.com/v1/playlists/5F1aBXHMHi1vEsjzhIR4ZM',
#   'id': '5F1aBXHMHi1vEsjzhIR4ZM',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b2735e570fc1d95bbf490f8d05cdab67616d0000b273841a15650b658dc76bb02996ab67616d0000b2738f3fa78166f4a7e2d28eb201ab67616d0000b273f08405c87833b6096b62bbf6',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b2735e570fc1d95bbf490f8d05cdab67616d0000b273841a15650b658dc76bb02996ab67616d0000b2738f3fa78166f4a7e2d28eb201ab67616d0000b273f08405c87833b6096b62bbf6',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b2735e570fc1d95bbf490f8d05cdab67616d0000b273841a15650b658dc76bb02996ab67616d0000b2738f3fa78166f4a7e2d28eb201ab67616d0000b273f08405c87833b6096b62bbf6',
#     'width': 60}],
#   'name': 'Jazz-House',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'NCw4YjNmODBhMTY3YjA5ZWZhYjg5OGM4OTUwNDNjMzJiM2I3MTllOTVh',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/5F1aBXHMHi1vEsjzhIR4ZM/tracks',
#    'total': 31},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:5F1aBXHMHi1vEsjzhIR4ZM'},
#  {'collaborative': False,
#   'description': 'Dancehall song highlights from allmusic.com',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/2fpe5SLYvKs2dxBPwfQpx7'},
#   'href': 'https://api.spotify.com/v1/playlists/2fpe5SLYvKs2dxBPwfQpx7',
#   'id': '2fpe5SLYvKs2dxBPwfQpx7',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b273168c4bd1693a3ed83e323c1dab67616d0000b27338137595c83f6f37364f5a3bab67616d0000b27383c837321b9a3399dadb6b28ab67616d0000b273a3da9aa796119be94ec18948',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b273168c4bd1693a3ed83e323c1dab67616d0000b27338137595c83f6f37364f5a3bab67616d0000b27383c837321b9a3399dadb6b28ab67616d0000b273a3da9aa796119be94ec18948',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b273168c4bd1693a3ed83e323c1dab67616d0000b27338137595c83f6f37364f5a3bab67616d0000b27383c837321b9a3399dadb6b28ab67616d0000b273a3da9aa796119be94ec18948',
#     'width': 60}],
#   'name': 'Dancehall',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'NCw3YzljNTZkZmI5MWI3MDFiYTZlNzdjZmU5Y2VkZjJiYjQwMjM0MmQ4',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/2fpe5SLYvKs2dxBPwfQpx7/tracks',
#    'total': 36},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:2fpe5SLYvKs2dxBPwfQpx7'},
#  {'collaborative': False,
#   'description': 'Ragga song highlights from allmusic.com',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/5hszPJU8vFYtRqBw5aVv8y'},
#   'href': 'https://api.spotify.com/v1/playlists/5hszPJU8vFYtRqBw5aVv8y',
#   'id': '5hszPJU8vFYtRqBw5aVv8y',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b27311394cad51642144dc4014b3ab67616d0000b27348427faaf96a3dec0dcf91cbab67616d0000b273a3d8cec0d649109f7413367bab67616d0000b273f615507b4b847d5865d8c7ff',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b27311394cad51642144dc4014b3ab67616d0000b27348427faaf96a3dec0dcf91cbab67616d0000b273a3d8cec0d649109f7413367bab67616d0000b273f615507b4b847d5865d8c7ff',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b27311394cad51642144dc4014b3ab67616d0000b27348427faaf96a3dec0dcf91cbab67616d0000b273a3d8cec0d649109f7413367bab67616d0000b273f615507b4b847d5865d8c7ff',
#     'width': 60}],
#   'name': 'Ragga',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'NCxmOTA3NWZlNDg4MDdjMWY4NjcxNTE4OWFjOTQ4M2YwMGMzMzY3YmQ5',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/5hszPJU8vFYtRqBw5aVv8y/tracks',
#    'total': 45},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:5hszPJU8vFYtRqBw5aVv8y'},
#  {'collaborative': False,
#   'description': 'Soca song highlights from allmusic.com',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/7FtkxYI8OvHFfzTHOMl1Ma'},
#   'href': 'https://api.spotify.com/v1/playlists/7FtkxYI8OvHFfzTHOMl1Ma',
#   'id': '7FtkxYI8OvHFfzTHOMl1Ma',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b2733e86a0af3c8b40a9325eb79fab67616d0000b2737701fa188b0ef37d15dfa986ab67616d0000b27390aa31b02a0276133133e88eab67616d0000b273a5d8129d4dfe77e657a62fc2',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b2733e86a0af3c8b40a9325eb79fab67616d0000b2737701fa188b0ef37d15dfa986ab67616d0000b27390aa31b02a0276133133e88eab67616d0000b273a5d8129d4dfe77e657a62fc2',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b2733e86a0af3c8b40a9325eb79fab67616d0000b2737701fa188b0ef37d15dfa986ab67616d0000b27390aa31b02a0276133133e88eab67616d0000b273a5d8129d4dfe77e657a62fc2',
#     'width': 60}],
#   'name': 'Soca',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'Niw0NTA4YzhjMDIxYjZiMDRkZGNjMmU4ZjRiNTVhYmZlYWM5MmNlMTlj',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/7FtkxYI8OvHFfzTHOMl1Ma/tracks',
#    'total': 27},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:7FtkxYI8OvHFfzTHOMl1Ma'},
#  {'collaborative': False,
#   'description': 'Dub song highlights from allmusic.com',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/3tyGJTWQJZGdCHZvZPpR5G'},
#   'href': 'https://api.spotify.com/v1/playlists/3tyGJTWQJZGdCHZvZPpR5G',
#   'id': '3tyGJTWQJZGdCHZvZPpR5G',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b27300b80c40d25750a320d21263ab67616d0000b273aa47e1987a99a219e0ccbdb7ab67616d0000b273ac43949f7a0104ef9d57c21fab67616d0000b273bf4b65b4e45b325797abf60c',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b27300b80c40d25750a320d21263ab67616d0000b273aa47e1987a99a219e0ccbdb7ab67616d0000b273ac43949f7a0104ef9d57c21fab67616d0000b273bf4b65b4e45b325797abf60c',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b27300b80c40d25750a320d21263ab67616d0000b273aa47e1987a99a219e0ccbdb7ab67616d0000b273ac43949f7a0104ef9d57c21fab67616d0000b273bf4b65b4e45b325797abf60c',
#     'width': 60}],
#   'name': 'Dub',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'NCwwNGRlYmFjMjk5ZGNjODUyMjRiZTYwYzIzZjUxZjM4NWIxMDI2ZDUy',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/3tyGJTWQJZGdCHZvZPpR5G/tracks',
#    'total': 31},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:3tyGJTWQJZGdCHZvZPpR5G'},
#  {'collaborative': False,
#   'description': 'Lovers Rock song highlights from allmusic.com',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/57niHqfEE55VxeefCcuYQ7'},
#   'href': 'https://api.spotify.com/v1/playlists/57niHqfEE55VxeefCcuYQ7',
#   'id': '57niHqfEE55VxeefCcuYQ7',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b273485ab0f24fab665d83e90068ab67616d0000b273a67abbba71f97bae659af8ceab67616d0000b273b6960dcd965137037003c10eab67616d0000b273d95ae7dad16e122d060cd14b',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b273485ab0f24fab665d83e90068ab67616d0000b273a67abbba71f97bae659af8ceab67616d0000b273b6960dcd965137037003c10eab67616d0000b273d95ae7dad16e122d060cd14b',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b273485ab0f24fab665d83e90068ab67616d0000b273a67abbba71f97bae659af8ceab67616d0000b273b6960dcd965137037003c10eab67616d0000b273d95ae7dad16e122d060cd14b',
#     'width': 60}],
#   'name': 'Lovers Rock',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'NCwwOTdiN2YzNWRhM2E5OWQ0MDZhODRhODg2OWJmNDM0ODVmZDc0NjI3',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/57niHqfEE55VxeefCcuYQ7/tracks',
#    'total': 40},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:57niHqfEE55VxeefCcuYQ7'},
#  {'collaborative': False,
#   'description': 'Roots Reggae song highlights from allmusic.com',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/0Zoz8mGOcO8SXTMHvqO3Mr'},
#   'href': 'https://api.spotify.com/v1/playlists/0Zoz8mGOcO8SXTMHvqO3Mr',
#   'id': '0Zoz8mGOcO8SXTMHvqO3Mr',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b2733080f5a0098da4b2c46b2938ab67616d0000b273995588ad272e39bfc75016a3ab67616d0000b2739c7b208c7c3ecdb325613d34ab67616d0000b273e77a671e859f14fd2f222bac',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b2733080f5a0098da4b2c46b2938ab67616d0000b273995588ad272e39bfc75016a3ab67616d0000b2739c7b208c7c3ecdb325613d34ab67616d0000b273e77a671e859f14fd2f222bac',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b2733080f5a0098da4b2c46b2938ab67616d0000b273995588ad272e39bfc75016a3ab67616d0000b2739c7b208c7c3ecdb325613d34ab67616d0000b273e77a671e859f14fd2f222bac',
#     'width': 60}],
#   'name': 'Roots Reggae',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'NCw1ZjliODdkYjU1YTZmMTdhNWU1YWNhZmQ2OWNhMDExOTc3NDhlYmZi',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/0Zoz8mGOcO8SXTMHvqO3Mr/tracks',
#    'total': 44},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:0Zoz8mGOcO8SXTMHvqO3Mr'},
#  {'collaborative': False,
#   'description': 'Disco song highlights from allmusic.com',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/318e4Nc7Cc9byZ7jX8f7dD'},
#   'href': 'https://api.spotify.com/v1/playlists/318e4Nc7Cc9byZ7jX8f7dD',
#   'id': '318e4Nc7Cc9byZ7jX8f7dD',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b2737a816fa75d970464b5ac29beab67616d0000b2738be7a811c839f3485de9647fab67616d0000b273d12c40e9c2140939ac4ba130ab67616d0000b273e2c1f7c1ee0ee027f41178fd',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b2737a816fa75d970464b5ac29beab67616d0000b2738be7a811c839f3485de9647fab67616d0000b273d12c40e9c2140939ac4ba130ab67616d0000b273e2c1f7c1ee0ee027f41178fd',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b2737a816fa75d970464b5ac29beab67616d0000b2738be7a811c839f3485de9647fab67616d0000b273d12c40e9c2140939ac4ba130ab67616d0000b273e2c1f7c1ee0ee027f41178fd',
#     'width': 60}],
#   'name': 'Disco',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'NCxiNmNmZTkwMzM0Nzg5MzlmMjI2YjRmNzZjODhiN2ZmMzIxMmE1NWMy',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/318e4Nc7Cc9byZ7jX8f7dD/tracks',
#    'total': 33},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:318e4Nc7Cc9byZ7jX8f7dD'},
#  {'collaborative': False,
#   'description': 'Deep Funk Revival song highlights from allmusic.com',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/1QeFov6j2uSPJ2CE3JsZhL'},
#   'href': 'https://api.spotify.com/v1/playlists/1QeFov6j2uSPJ2CE3JsZhL',
#   'id': '1QeFov6j2uSPJ2CE3JsZhL',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b27309268fcf99197e5289a3870aab67616d0000b2737c4a6e25b31b05750f77180cab67616d0000b273c477c230265136cdd54bcb41ab67616d0000b273db990a6b9f9d29f4310289b1',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b27309268fcf99197e5289a3870aab67616d0000b2737c4a6e25b31b05750f77180cab67616d0000b273c477c230265136cdd54bcb41ab67616d0000b273db990a6b9f9d29f4310289b1',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b27309268fcf99197e5289a3870aab67616d0000b2737c4a6e25b31b05750f77180cab67616d0000b273c477c230265136cdd54bcb41ab67616d0000b273db990a6b9f9d29f4310289b1',
#     'width': 60}],
#   'name': 'Deep Funk Revival',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'NSw1ZjhjMWFmMTAyZDM3ZmM4ODk5ZWVkMWI1NjhiMTc5NmQxNTI5MWZh',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/1QeFov6j2uSPJ2CE3JsZhL/tracks',
#    'total': 42},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:1QeFov6j2uSPJ2CE3JsZhL'},
#  {'collaborative': False,
#   'description': 'Deep Funk song highlights from allmusic.com',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/3Z88R9JITTTARqxRoyfSqp'},
#   'href': 'https://api.spotify.com/v1/playlists/3Z88R9JITTTARqxRoyfSqp',
#   'id': '3Z88R9JITTTARqxRoyfSqp',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b27314a2ce9a383495432a8157ddab67616d0000b2734f3973e8080205a445cb8a98ab67616d0000b2737eb310880bbdde90c0411632ab67616d0000b273813c63f976044f239d74b696',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b27314a2ce9a383495432a8157ddab67616d0000b2734f3973e8080205a445cb8a98ab67616d0000b2737eb310880bbdde90c0411632ab67616d0000b273813c63f976044f239d74b696',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b27314a2ce9a383495432a8157ddab67616d0000b2734f3973e8080205a445cb8a98ab67616d0000b2737eb310880bbdde90c0411632ab67616d0000b273813c63f976044f239d74b696',
#     'width': 60}],
#   'name': 'Deep Funk',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'NCxiNjEwODEwZmRlYjdlNmZjNTE0ZDU3ODY4NzgwM2VkZTkzZTlmNzY3',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/3Z88R9JITTTARqxRoyfSqp/tracks',
#    'total': 36},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:3Z88R9JITTTARqxRoyfSqp'},
#  {'collaborative': False,
#   'description': '',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/3cqLAJrcSpZJcarmbHS6Lu'},
#   'href': 'https://api.spotify.com/v1/playlists/3cqLAJrcSpZJcarmbHS6Lu',
#   'id': '3cqLAJrcSpZJcarmbHS6Lu',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b273175c577a61aa13d4fb4b6534ab67616d0000b27354de35ac4fc5d8ed1ec1d956ab67616d0000b2737a9400f8110b9192eb986a2dab67616d0000b273e5342f5ba209ac94fa5dab6f',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b273175c577a61aa13d4fb4b6534ab67616d0000b27354de35ac4fc5d8ed1ec1d956ab67616d0000b2737a9400f8110b9192eb986a2dab67616d0000b273e5342f5ba209ac94fa5dab6f',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b273175c577a61aa13d4fb4b6534ab67616d0000b27354de35ac4fc5d8ed1ec1d956ab67616d0000b2737a9400f8110b9192eb986a2dab67616d0000b273e5342f5ba209ac94fa5dab6f',
#     'width': 60}],
#   'name': 'OpenBroadcast - In Bed (by blundetto)',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'NyxiZGI2OTVlNzUzNjgwMjI0ZmVhNzY3ZmY0MGFjNGU0NzliNDZjNjkx',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/3cqLAJrcSpZJcarmbHS6Lu/tracks',
#    'total': 265},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:3cqLAJrcSpZJcarmbHS6Lu'},
#  {'collaborative': False,
#   'description': '',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/0pHYv453jlgikljjzrGKrf'},
#   'href': 'https://api.spotify.com/v1/playlists/0pHYv453jlgikljjzrGKrf',
#   'id': '0pHYv453jlgikljjzrGKrf',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b27327183ee1bd839e742234fb7cab67616d0000b2734399ed91560b249f57044582ab67616d0000b2734c5901b8addcbf59bc55ecaaab67616d0000b2734ed76176a89ccd907d5f24c9',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b27327183ee1bd839e742234fb7cab67616d0000b2734399ed91560b249f57044582ab67616d0000b2734c5901b8addcbf59bc55ecaaab67616d0000b2734ed76176a89ccd907d5f24c9',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b27327183ee1bd839e742234fb7cab67616d0000b2734399ed91560b249f57044582ab67616d0000b2734c5901b8addcbf59bc55ecaaab67616d0000b2734ed76176a89ccd907d5f24c9',
#     'width': 60}],
#   'name': 'Jalapeno Funk',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'MTQsZDYxNDUxMjdkNzM2YzBmNThhNjlmOWI5MzdhMTdlNzI4Y2VhZWFmMA==',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/0pHYv453jlgikljjzrGKrf/tracks',
#    'total': 207},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:0pHYv453jlgikljjzrGKrf'},
#  {'collaborative': False,
#   'description': 'My favorite easy listening tracks made in this millenium',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/566s1zzyRtF4bzv9JfpnVY'},
#   'href': 'https://api.spotify.com/v1/playlists/566s1zzyRtF4bzv9JfpnVY',
#   'id': '566s1zzyRtF4bzv9JfpnVY',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b2730ec1d9ae6b17037e60708bd9ab67616d0000b273b531c34ad713e15aa8c6fbd9ab67616d0000b273b9b9be1327c427955b83b725ab67616d0000b273f2fea8c924ef28093f17d277',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b2730ec1d9ae6b17037e60708bd9ab67616d0000b273b531c34ad713e15aa8c6fbd9ab67616d0000b273b9b9be1327c427955b83b725ab67616d0000b273f2fea8c924ef28093f17d277',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b2730ec1d9ae6b17037e60708bd9ab67616d0000b273b531c34ad713e15aa8c6fbd9ab67616d0000b273b9b9be1327c427955b83b725ab67616d0000b273f2fea8c924ef28093f17d277',
#     'width': 60}],
#   'name': 'Pop2000',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'MTA2LDA2YTg5Y2JjMmRmNjM4NTcxODhiZjEwYmZmNmQ2MjdiZTBmMTA5Yjc=',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/566s1zzyRtF4bzv9JfpnVY/tracks',
#    'total': 1155},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:566s1zzyRtF4bzv9JfpnVY'},
#  {'collaborative': False,
#   'description': 'My favorite Hard Bop and Cool Jazz albums',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/6llGZ072CW6nCfZnP4IRpI'},
#   'href': 'https://api.spotify.com/v1/playlists/6llGZ072CW6nCfZnP4IRpI',
#   'id': '6llGZ072CW6nCfZnP4IRpI',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b27301ffa1c7915624b95b9065e0ab67616d0000b27342a04303e6eb1100df3ea036ab67616d0000b2737ab89c25093ea3787b1995b4ab67616d0000b273bb3ca42fa0a3f2f39143c9ab',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b27301ffa1c7915624b95b9065e0ab67616d0000b27342a04303e6eb1100df3ea036ab67616d0000b2737ab89c25093ea3787b1995b4ab67616d0000b273bb3ca42fa0a3f2f39143c9ab',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b27301ffa1c7915624b95b9065e0ab67616d0000b27342a04303e6eb1100df3ea036ab67616d0000b2737ab89c25093ea3787b1995b4ab67616d0000b273bb3ca42fa0a3f2f39143c9ab',
#     'width': 60}],
#   'name': 'Classic Jazz',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'MTY3LDlkYjNiOTRmMjdhMTBmNmE3MzJhNTVlNGIxMTc2N2M0OGUwMTBhZDA=',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/6llGZ072CW6nCfZnP4IRpI/tracks',
#    'total': 417},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:6llGZ072CW6nCfZnP4IRpI'},
#  {'collaborative': False,
#   'description': '',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/31tFGldLHHeWvitXFG721v'},
#   'href': 'https://api.spotify.com/v1/playlists/31tFGldLHHeWvitXFG721v',
#   'id': '31tFGldLHHeWvitXFG721v',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b2730605c53b2b2a0c9f29d7cb16ab67616d0000b2736eee52ed60a33a81d888720aab67616d0000b2737ab89c25093ea3787b1995b4ab67616d0000b273c00913832628c23c7952ae7b',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b2730605c53b2b2a0c9f29d7cb16ab67616d0000b2736eee52ed60a33a81d888720aab67616d0000b2737ab89c25093ea3787b1995b4ab67616d0000b273c00913832628c23c7952ae7b',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b2730605c53b2b2a0c9f29d7cb16ab67616d0000b2736eee52ed60a33a81d888720aab67616d0000b2737ab89c25093ea3787b1995b4ab67616d0000b273c00913832628c23c7952ae7b',
#     'width': 60}],
#   'name': 'Uptempo Jazz',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'OTgsYjMwZjU0OTI5ZjU4MmIwMzE3NGVkYmYyOTQ1OWM1NDU0MjdkNGU0Yg==',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/31tFGldLHHeWvitXFG721v/tracks',
#    'total': 95},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:31tFGldLHHeWvitXFG721v'},
#  {'collaborative': False,
#   'description': 'Old and new, mellow and wild',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/08CVuk5TKfBivxwWz0zu1X'},
#   'href': 'https://api.spotify.com/v1/playlists/08CVuk5TKfBivxwWz0zu1X',
#   'id': '08CVuk5TKfBivxwWz0zu1X',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b2735de02d26973639bf6f1eea25ab67616d0000b273b3a41184ba752731d19d8ef0ab67616d0000b273cd1ea8639de6d3f827fba218ab67616d0000b273d971b1f9ac40254d9643951b',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b2735de02d26973639bf6f1eea25ab67616d0000b273b3a41184ba752731d19d8ef0ab67616d0000b273cd1ea8639de6d3f827fba218ab67616d0000b273d971b1f9ac40254d9643951b',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b2735de02d26973639bf6f1eea25ab67616d0000b273b3a41184ba752731d19d8ef0ab67616d0000b273cd1ea8639de6d3f827fba218ab67616d0000b273d971b1f9ac40254d9643951b',
#     'width': 60}],
#   'name': 'Vocal Jazz',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'MTI5LGMxNWI5MzA2YzE1OWI1YzljZjlkOTA2YjRlOGEzYTVkY2E0ZWI0NTM=',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/08CVuk5TKfBivxwWz0zu1X/tracks',
#    'total': 94},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:08CVuk5TKfBivxwWz0zu1X'},
#  {'collaborative': False,
#   'description': '',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/489J1YM8xmRKwJ0KJCrDgM'},
#   'href': 'https://api.spotify.com/v1/playlists/489J1YM8xmRKwJ0KJCrDgM',
#   'id': '489J1YM8xmRKwJ0KJCrDgM',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b2730605c53b2b2a0c9f29d7cb16ab67616d0000b2736eee52ed60a33a81d888720aab67616d0000b2737ab89c25093ea3787b1995b4ab67616d0000b273c00913832628c23c7952ae7b',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b2730605c53b2b2a0c9f29d7cb16ab67616d0000b2736eee52ed60a33a81d888720aab67616d0000b2737ab89c25093ea3787b1995b4ab67616d0000b273c00913832628c23c7952ae7b',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b2730605c53b2b2a0c9f29d7cb16ab67616d0000b2736eee52ed60a33a81d888720aab67616d0000b2737ab89c25093ea3787b1995b4ab67616d0000b273c00913832628c23c7952ae7b',
#     'width': 60}],
#   'name': 'Dinner Jazz',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'MTQwLDdkOGMwNGFkYTQxNjc4YTExODI4NTllMzg1ODY4ZjlkYjliZWU5Zjg=',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/489J1YM8xmRKwJ0KJCrDgM/tracks',
#    'total': 633},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:489J1YM8xmRKwJ0KJCrDgM'},
#  {'collaborative': False,
#   'description': 'Jazzy stuff with fat grooves',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/6yCyQLKLPHmNAM1qfXxaT2'},
#   'href': 'https://api.spotify.com/v1/playlists/6yCyQLKLPHmNAM1qfXxaT2',
#   'id': '6yCyQLKLPHmNAM1qfXxaT2',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b273114428ac94fcf08cd3052d07ab67616d0000b273b7f6bd0254a09914235ea128ab67616d0000b273c438365ea0ec47a018e2010aab67616d0000b273fc390ce6c14df3557c4336a4',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b273114428ac94fcf08cd3052d07ab67616d0000b273b7f6bd0254a09914235ea128ab67616d0000b273c438365ea0ec47a018e2010aab67616d0000b273fc390ce6c14df3557c4336a4',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b273114428ac94fcf08cd3052d07ab67616d0000b273b7f6bd0254a09914235ea128ab67616d0000b273c438365ea0ec47a018e2010aab67616d0000b273fc390ce6c14df3557c4336a4',
#     'width': 60}],
#   'name': 'Phat Jazz',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'MTY1LGU1YWMzZTYyZjg3ZGJlYTZmODRkMmY1YjVjZDg2NDgzNjY2Y2QwZGE=',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/6yCyQLKLPHmNAM1qfXxaT2/tracks',
#    'total': 155},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:6yCyQLKLPHmNAM1qfXxaT2'},
#  {'collaborative': False,
#   'description': '',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/5ngdqzXvg3v6yakZ6oAcxv'},
#   'href': 'https://api.spotify.com/v1/playlists/5ngdqzXvg3v6yakZ6oAcxv',
#   'id': '5ngdqzXvg3v6yakZ6oAcxv',
#   'images': [{'height': None,
#     'url': 'https://i.scdn.co/image/ab67706c0000bebb3f5a22ac3e3d9506f4218e8a',
#     'width': None}],
#   'name': 'Trojan Archives',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'MjQsNGU2OWMxMGYzOGVmYmUwYjQ1MTAxNTE2N2U1MmUwNzQ2NTg0MGE1Ng==',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/5ngdqzXvg3v6yakZ6oAcxv/tracks',
#    'total': 749},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:5ngdqzXvg3v6yakZ6oAcxv'},
#  {'collaborative': False,
#   'description': '',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/1npiimUFPnfOMfFKrwyc01'},
#   'href': 'https://api.spotify.com/v1/playlists/1npiimUFPnfOMfFKrwyc01',
#   'id': '1npiimUFPnfOMfFKrwyc01',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b27324c6586919c7353089d78ed0ab67616d0000b27383105a5782b137639b9529a7ab67616d0000b273a36b4e921833c21b60615830ab67616d0000b273ecc82c3ccb686800dbf4426f',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b27324c6586919c7353089d78ed0ab67616d0000b27383105a5782b137639b9529a7ab67616d0000b273a36b4e921833c21b60615830ab67616d0000b273ecc82c3ccb686800dbf4426f',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b27324c6586919c7353089d78ed0ab67616d0000b27383105a5782b137639b9529a7ab67616d0000b273a36b4e921833c21b60615830ab67616d0000b273ecc82c3ccb686800dbf4426f',
#     'width': 60}],
#   'name': '5 Star Hard Bop Albums',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'NzcsYWJkMWY5NzhmY2E2MjdjYTY5NDhiNTA0Zjg0NGU2ODc5Mzc0Nzk3MQ==',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/1npiimUFPnfOMfFKrwyc01/tracks',
#    'total': 534},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:1npiimUFPnfOMfFKrwyc01'},
#  {'collaborative': False,
#   'description': '',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/1FUKz6E2K5ldoAd4wbG8Ew'},
#   'href': 'https://api.spotify.com/v1/playlists/1FUKz6E2K5ldoAd4wbG8Ew',
#   'id': '1FUKz6E2K5ldoAd4wbG8Ew',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b2730ebc17239b6b18ba88cfb8caab67616d0000b2730f81ed1bf84b3585a8492d3dab67616d0000b27319d9b2d8f296f97d144b0523ab67616d0000b273c653150f8ed1f6a12348ba79',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b2730ebc17239b6b18ba88cfb8caab67616d0000b2730f81ed1bf84b3585a8492d3dab67616d0000b27319d9b2d8f296f97d144b0523ab67616d0000b273c653150f8ed1f6a12348ba79',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b2730ebc17239b6b18ba88cfb8caab67616d0000b2730f81ed1bf84b3585a8492d3dab67616d0000b27319d9b2d8f296f97d144b0523ab67616d0000b273c653150f8ed1f6a12348ba79',
#     'width': 60}],
#   'name': 'Top hard bop tracks',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'MTcsMzQzYjY3OGYyMmRlY2M4ZGI4MmM4NWM3MTEyNGM1MWYxOTY4Zjk5Mw==',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/1FUKz6E2K5ldoAd4wbG8Ew/tracks',
#    'total': 90},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:1FUKz6E2K5ldoAd4wbG8Ew'},
#  {'collaborative': False,
#   'description': '',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/69YjiqBUyv672XV0n1RQrv'},
#   'href': 'https://api.spotify.com/v1/playlists/69YjiqBUyv672XV0n1RQrv',
#   'id': '69YjiqBUyv672XV0n1RQrv',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b2730ebc17239b6b18ba88cfb8caab67616d0000b273206674cfc010f98e80b2ee8bab67616d0000b273710444d313a55d9f53dbea6eab67616d0000b273d5578146fd6cb97040f7d8bc',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b2730ebc17239b6b18ba88cfb8caab67616d0000b273206674cfc010f98e80b2ee8bab67616d0000b273710444d313a55d9f53dbea6eab67616d0000b273d5578146fd6cb97040f7d8bc',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b2730ebc17239b6b18ba88cfb8caab67616d0000b273206674cfc010f98e80b2ee8bab67616d0000b273710444d313a55d9f53dbea6eab67616d0000b273d5578146fd6cb97040f7d8bc',
#     'width': 60}],
#   'name': 'Top bebop tracks',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'MywzOGZhMGM1NDUzYmQyYmQ0Zjg2ODBhMDE5ZjVhNjkyYTYyYWE3OTQ2',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/69YjiqBUyv672XV0n1RQrv/tracks',
#    'total': 100},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:69YjiqBUyv672XV0n1RQrv'},
#  {'collaborative': False,
#   'description': '',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/0Ou5HSpnMa1Sc9uZZjnOOa'},
#   'href': 'https://api.spotify.com/v1/playlists/0Ou5HSpnMa1Sc9uZZjnOOa',
#   'id': '0Ou5HSpnMa1Sc9uZZjnOOa',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b273336671846b25f89e98bdf304ab67616d0000b2734a40c86ad6d2e16cdd73b1cdab67616d0000b2739a600c2a50302f3504b73f73ab67616d0000b273f561fb4dae287d5f8a4f4ccc',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b273336671846b25f89e98bdf304ab67616d0000b2734a40c86ad6d2e16cdd73b1cdab67616d0000b2739a600c2a50302f3504b73f73ab67616d0000b273f561fb4dae287d5f8a4f4ccc',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b273336671846b25f89e98bdf304ab67616d0000b2734a40c86ad6d2e16cdd73b1cdab67616d0000b2739a600c2a50302f3504b73f73ab67616d0000b273f561fb4dae287d5f8a4f4ccc',
#     'width': 60}],
#   'name': 'The Vibe!',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'MTEsM2M1NGZkZDlhMGM0NGE1ZGMzYTEwYjE1MjE1MjMxZjg3ZTVhZjFiNg==',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/0Ou5HSpnMa1Sc9uZZjnOOa/tracks',
#    'total': 123},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:0Ou5HSpnMa1Sc9uZZjnOOa'},
#  {'collaborative': False,
#   'description': '',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/7pUXPo3ScNlpk4npAdXfg4'},
#   'href': 'https://api.spotify.com/v1/playlists/7pUXPo3ScNlpk4npAdXfg4',
#   'id': '7pUXPo3ScNlpk4npAdXfg4',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b273a2a703e2f8f6af5e55c086dcab67616d0000b273aa386b9d692acdeaa4d8da38ab67616d0000b273b2f8b4f527ee54d0b6b66175ab67616d0000b273fc11f1091f721ae8afb98d7f',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b273a2a703e2f8f6af5e55c086dcab67616d0000b273aa386b9d692acdeaa4d8da38ab67616d0000b273b2f8b4f527ee54d0b6b66175ab67616d0000b273fc11f1091f721ae8afb98d7f',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b273a2a703e2f8f6af5e55c086dcab67616d0000b273aa386b9d692acdeaa4d8da38ab67616d0000b273b2f8b4f527ee54d0b6b66175ab67616d0000b273fc11f1091f721ae8afb98d7f',
#     'width': 60}],
#   'name': 'BeBop Deluxe',
#   'owner': {'display_name': 'jazzifyapp',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/jazzifyapp'},
#    'href': 'https://api.spotify.com/v1/users/jazzifyapp',
#    'id': 'jazzifyapp',
#    'type': 'user',
#    'uri': 'spotify:user:jazzifyapp'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'Myw0MjM1MDE2MGU0NDZkMjE2OGNhNWQyOGJlMzFiYmZlODcyZTY0MWJi',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/7pUXPo3ScNlpk4npAdXfg4/tracks',
#    'total': 20},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:7pUXPo3ScNlpk4npAdXfg4'},
#  {'collaborative': False,
#   'description': '',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/3ELlsCnc7nAqbhFC53U2W8'},
#   'href': 'https://api.spotify.com/v1/playlists/3ELlsCnc7nAqbhFC53U2W8',
#   'id': '3ELlsCnc7nAqbhFC53U2W8',
#   'images': [{'height': 640,
#     'url': 'https://mosaic.scdn.co/640/ab67616d0000b2731a4d24bb05a7de3ec7fb26c3ab67616d0000b2733dc7720d9734bf59be7ddf0dab67616d0000b2738e05a1075eada1ffe2889aa1ab67616d0000b27392814491369f15e56003306b',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://mosaic.scdn.co/300/ab67616d0000b2731a4d24bb05a7de3ec7fb26c3ab67616d0000b2733dc7720d9734bf59be7ddf0dab67616d0000b2738e05a1075eada1ffe2889aa1ab67616d0000b27392814491369f15e56003306b',
#     'width': 300},
#    {'height': 60,
#     'url': 'https://mosaic.scdn.co/60/ab67616d0000b2731a4d24bb05a7de3ec7fb26c3ab67616d0000b2733dc7720d9734bf59be7ddf0dab67616d0000b2738e05a1075eada1ffe2889aa1ab67616d0000b27392814491369f15e56003306b',
#     'width': 60}],
#   'name': 'Orhan',
#   'owner': {'display_name': 'Mehmet Birgi',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/mbirgi'},
#    'href': 'https://api.spotify.com/v1/users/mbirgi',
#    'id': 'mbirgi',
#    'type': 'user',
#    'uri': 'spotify:user:mbirgi'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'Miw5MGZlNmIyZjcxMDQ5YTQzN2RmODM3NjA5OGU1ZWQ2YzQ3YTVjNjA3',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/3ELlsCnc7nAqbhFC53U2W8/tracks',
#    'total': 20},
#   'type': 'playlist',
#   'uri': 'spotify:playlist:3ELlsCnc7nAqbhFC53U2W8'}]

# %%
# save the playlists as a list of dictionaries
import json
import os
folder = 'data'
filename = 'all_my_playlists.json'
if not os.path.exists(folder):
    os.mkdir(folder)
with open(os.path.join(folder, filename), 'w', encoding='utf-8') as f:
    json.dump(all_playlists, f, ensure_ascii=False, indent=4)

# %%
# extract all tracks from playlists
playlist_ids = [playlist['id'] for playlist in all_playlists]
all_playlist_tracks = [item['track'] for item in spotify.get_tracks_in_playlists(sp, playlist_ids)]
len(all_playlist_tracks)
# Out:
# 39144

# %%
# extract the pertinent information
all_tracks = []
for track in all_playlist_tracks:
    name = track['name']
    artists = [{'name': artist['name'], 'id': artist['id']} for artist in track['artists']]
    track_id = track['id']
    duration_ms = track['duration_ms']
    all_tracks.append({
        'name': name,
        'artists': artists,
        'id': track_id,
        'duration_ms': duration_ms
    })
len(all_tracks)
# Out:
# 39144

# %%
# save the tracks
import json
import os
folder = 'data'
filename = 'all_my_playlist_tracks.json'
if not os.path.exists(folder):
    os.mkdir(folder)
with open(os.path.join(folder, filename), 'w', encoding='utf-8') as f:
    json.dump(all_tracks, f, ensure_ascii=False, indent=4)

# %%
# get all 'liked' tracks and add them to the tally
results = sp.current_user_saved_tracks(limit=50)
saved_tracks = results['items']
while results['next']:
    results = sp.next(results)
    saved_tracks.extend(results['items'])
for item in saved_tracks:
    name = item['track']['name']
    artists = [{'name': artist['name'], 'id': artist['id']} for artist in item['track']['artists']]
    track_id = item['track']['id']
    duration_ms = item['track']['duration_ms']
    all_tracks.append({
        'name': name,
        'artists': artists,
        'id': track_id,
        'duration_ms': duration_ms
    })
len(all_tracks)
# Out:
# 39307

# %%
all_tracks[14458]
# Out:
# {'name': 'Candlelight',
#  'artists': [{'name': 'Donald Harrison', 'id': '53pHwg1sjhqGk726JnJHYb'},
#   {'name': 'Ron Carter', 'id': '4wnzivx3OQ3vjrySAdTdJP'},
#   {'name': 'Billy Cobham', 'id': '0IwfuIL3gUJxjzUqY3wJ3j'}],
#  'id': '0YvppvxUQYXPNFF00iYLxz',
#  'duration_ms': 393293}

# %%
# get saved album tracks and add them to the tally
results = sp.current_user_saved_albums(limit=50)
saved_albums = results['items']
while results['next']:
    results = sp.next(results)
    saved_albums.extend(results['items'])
len(saved_albums)
saved_album_tracks = []
for album in saved_albums:
    results = sp.album_tracks(album['album']['id'])
    album_tracks = results['items']
    while results['next']:
        results = sp.next(results)
        album_tracks.extend(results['items'])
    saved_album_tracks.extend(album_tracks)
album_tracks = []
for track in saved_album_tracks:
    name = track['name']
    artists = [{'name': artist['name'], 'id': artist['id']} for artist in track['artists']]
    track_id = track['id']
    duration_ms = track['duration_ms']
    album_tracks.append({
        'name': name,
        'artists': artists,
        'id': track_id,
        'duration_ms': duration_ms
    })
all_tracks.extend(album_tracks)

# %%
len(all_tracks)
# Out:
# 49079

# %%
# save tracks for later
import json
import os
folder = 'data'
filename = 'all_my_tracks.json'
if not os.path.exists(folder):
    os.mkdir(folder)
with open(os.path.join(folder, filename), 'w', encoding='utf-8') as f:
    json.dump(all_tracks, f, ensure_ascii=False, indent=4)

# %%
# read the tracks
import json
import os
folder = 'data'
filename = 'all_my_tracks.json'
with open(os.path.join(folder, filename), 'r', encoding='utf-8') as f:
    all_tracks = json.load(f)

# %%
len(all_tracks)
# Out:
# 49079

# %%
# get audio features
all_track_ids = [track['id'] for track in all_tracks]
audio_features = spotify.get_audio_features_for_tracks(sp, all_track_ids)

# %%
audio_features[:2]
# Out:
# [{'danceability': 0.838,
#   'energy': 0.764,
#   'key': 7,
#   'loudness': -5.076,
#   'mode': 0,
#   'speechiness': 0.0586,
#   'acousticness': 0.0862,
#   'instrumentalness': 0.000122,
#   'liveness': 0.0906,
#   'valence': 0.924,
#   'tempo': 133.592,
#   'type': 'audio_features',
#   'id': '023lag1AgeOf7YChojecRu',
#   'uri': 'spotify:track:023lag1AgeOf7YChojecRu',
#   'track_href': 'https://api.spotify.com/v1/tracks/023lag1AgeOf7YChojecRu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/023lag1AgeOf7YChojecRu',
#   'duration_ms': 161240,
#   'time_signature': 4},
#  {'danceability': 0.79,
#   'energy': 0.614,
#   'key': 11,
#   'loudness': -15.281,
#   'mode': 1,
#   'speechiness': 0.0942,
#   'acousticness': 0.174,
#   'instrumentalness': 0.497,
#   'liveness': 0.155,
#   'valence': 0.387,
#   'tempo': 111.01,
#   'type': 'audio_features',
#   'id': '33eZMP1iybo3VBrJJeMwob',
#   'uri': 'spotify:track:33eZMP1iybo3VBrJJeMwob',
#   'track_href': 'https://api.spotify.com/v1/tracks/33eZMP1iybo3VBrJJeMwob',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/33eZMP1iybo3VBrJJeMwob',
#   'duration_ms': 367567,
#   'time_signature': 4}]

# %%
len(audio_features)
# Out:
# 49079

# %%
# save tracks for later
import json
import os
folder = 'data'
filename = 'all_my_tracks_audio_features.json'
if not os.path.exists(folder):
    os.mkdir(folder)
with open(os.path.join(folder, filename), 'w', encoding='utf-8') as f:
    json.dump(audio_features, f, ensure_ascii=False, indent=4)

# %%
len(audio_features)
# Out:
# 49079

# %%
list(audio_features[0].keys())
# Out:
# ['danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature']

# %%
# check for invalid records
audio_features = [track for track in audio_features if track is not None]
len(audio_features)
# Out:
# 49073

# %%
df_audio_features = pd.DataFrame(audio_features).drop(columns=['type', 'uri', 'track_href', 'analysis_url'])

# %%
df_audio_features
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.838   0.764    7    -5.076     0       0.0586        0.0862
# 1             0.790   0.614   11   -15.281     1       0.0942        0.1740
# 2             0.909   0.407    6    -8.258     0       0.0669        0.1850
# 3             0.212   0.376    1   -34.734     1       0.0523        0.9660
# 4             0.579   0.661    0    -7.775     0       0.0357        0.0190
# ...             ...     ...  ...       ...   ...          ...           ...
# 49068         0.474   0.575    5    -9.952     1       0.0980        0.1750
# 49069         0.749   0.439    9   -14.898     1       0.0289        0.6490
# 49070         0.487   0.138    0   -10.839     1       0.0379        0.7490
# 49071         0.688   0.886    2   -11.154     1       0.0607        0.2820
# 49072         0.614   0.518   10   -11.202     1       0.1850        0.3570
#
#        instrumentalness  liveness  valence    tempo                      id  \
# 0              0.000122    0.0906   0.9240  133.592  023lag1AgeOf7YChojecRu
# 1              0.497000    0.1550   0.3870  111.010  33eZMP1iybo3VBrJJeMwob
# 2              0.000000    0.0757   0.5080  109.983  6N3KdEz4JPwHp6kfMdy1i9
# 3              0.645000    0.1100   0.0686   74.809  42o4C7nCvWDzZlwzojupL9
# 4              0.002160    0.1030   0.2050  134.036  2Qg0jbBO58hytXlhpaSeeB
# ...                 ...       ...      ...      ...                     ...
# 49068          0.000000    0.1880   0.7730  184.832  5EPJ4Vg1AkcOcLi0c6xWMG
# 49069          0.113000    0.0875   0.5750  123.203  4mpnyBVLtkRpvDVodedXeQ
# 49070          0.000028    0.1060   0.2330  121.062  1mkLqKwhZYU9z7CZQSaxW3
# 49071          0.002290    0.1620   0.5980  136.482  6FUMP0fyzWqhA3O64ap4o4
# 49072          0.000002    0.5710   0.8750  116.160  3PMcBrDbT8LCUjlNPx7Gp3
#
#        duration_ms  time_signature
# 0           161240               4
# 1           367567               4
# 2           187704               4
# 3           122328               3
# 4           173880               4
# ...            ...             ...
# 49068       239640               4
# 49069       222107               4
# 49070       214000               4
# 49071       196933               4
# 49072       114200               4
#
# [49073 rows x 14 columns]

# %% [markdown]
# ##### select the suitable tracks:

# %%
tempo_min, tempo_max = 135, 140
track_ids = set(df_audio_features[
    (df_audio_features['tempo'] >= tempo_min) & 
    (df_audio_features['tempo'] <= tempo_max) & 
    (df_audio_features['danceability'] >= 0.8) &
    (df_audio_features['liveness'] <= 0.4) &
    (df_audio_features['speechiness'] <= 0.33)
]['id'])
len(track_ids)
# Out:
# 129

# %%
playlist_id, is_new = spotify.get_playlist_by_name(sp, 
        f"BPM {tempo_min} - {tempo_max} All Tracks", 
        create_if_none=True)
if playlist_id and is_new:
    print(f"Created new playlist with ID {playlist_id}")
elif playlist_id:
    print(f"Found existing playlist with ID {playlist_id}")
else:
    print("Something went wrong :-(")
# Out:
# Created new playlist with ID 17EMIHwiUWgULJUBlqBCU6

# %%
spotify.add_tracks(sp, playlist_id, track_ids)

# %%
max_ids = 50
tracks_audio_features = []
track_ids = list(track_ids)
for i in range(0, len(track_ids), max_ids):
    results = sp.audio_features(track_ids[i:i+max_ids])
    tracks_audio_features.extend(results)
len(tracks_audio_features)
df_audio_features = pd.DataFrame(tracks_audio_features)
df_audio_features['tempo'].plot.hist()
