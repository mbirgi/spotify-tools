# %% [markdown]
# ### Scrapes playlists from Open Broadcast Radio

# %%
import pprint
import requests
from bs4 import BeautifulSoup as bs

pp = pprint.PrettyPrinter(indent=4)

# %% [markdown]
# #### scrape all playlists:

# %%
playlists = []
base_url = "https://www.openbroadcast.org"
href = "/content/playlists/?page=1"
while True:
    url = base_url + href
    response = requests.get(url)
    if response.status_code == 200:
        soup = bs(response.content)
        page_items = soup.find_all('div', class_='card--playlist')
        page_playlists = []
        for item in page_items:
            body = item.find('div', class_='card__body').find_all('div')
            playlist = {
                'title': " ".join(body[2].text.split()),
                'author': {
                    'name': body[4].text.strip(),
                    'href': body[4].a['href']
                },
                'href': body[0].a['href'],
                'tags': list(item.find('div', class_='tags').stripped_strings),
            }
            page_playlists.append(playlist)
        playlists.extend(page_playlists)
    else:
        print(f"error while scraping page {page}")
        print(f"    error code: {response.status_code}")
        print(f"    URL: {url}")
        continue
    pagination = soup.find('div', class_='pagination')
    current_page = pagination.find('span', class_='current page').text
    print(f"scraped page {current_page}")
    if pagination.find('span', class_='disabled next'):
        print("finished!")
        print(f"{len(playlists)} playlists in total")
        break
    href = pagination.find('a', class_='next')['href']
    print(f"next href: {href}")
    if current_page == "50":
        print("failsafe!")
        break
# Out:
# scraped page 1
# next href: /content/playlists/?page=2
# scraped page 2
# next href: /content/playlists/?page=3
# scraped page 3
# next href: /content/playlists/?page=4
# scraped page 4
# next href: /content/playlists/?page=5
# scraped page 5
# next href: /content/playlists/?page=6
# scraped page 6
# next href: /content/playlists/?page=7
# scraped page 7
# next href: /content/playlists/?page=8
# scraped page 8
# next href: /content/playlists/?page=9
# scraped page 9
# next href: /content/playlists/?page=10
# scraped page 10
# next href: /content/playlists/?page=11
# scraped page 11
# next href: /content/playlists/?page=12
# scraped page 12
# next href: /content/playlists/?page=13
# scraped page 13
# next href: /content/playlists/?page=14
# scraped page 14
# next href: /content/playlists/?page=15
# scraped page 15
# next href: /content/playlists/?page=16
# scraped page 16
# next href: /content/playlists/?page=17
# scraped page 17
# next href: /content/playlists/?page=18
# scraped page 18
# next href: /content/playlists/?page=19
# scraped page 19
# next href: /content/playlists/?page=20
# scraped page 20
# next href: /content/playlists/?page=21
# scraped page 21
# next href: /content/playlists/?page=22
# scraped page 22
# next href: /content/playlists/?page=23
# scraped page 23
# next href: /content/playlists/?page=24
# scraped page 24
# next href: /content/playlists/?page=25
# scraped page 25
# next href: /content/playlists/?page=26
# scraped page 26
# next href: /content/playlists/?page=27
# scraped page 27
# next href: /content/playlists/?page=28
# scraped page 28
# next href: /content/playlists/?page=29
# scraped page 29
# next href: /content/playlists/?page=30
# scraped page 30
# next href: /content/playlists/?page=31
# scraped page 31
# next href: /content/playlists/?page=32
# scraped page 32
# next href: /content/playlists/?page=33
# scraped page 33
# next href: /content/playlists/?page=34
# scraped page 34
# next href: /content/playlists/?page=35
# scraped page 35
# next href: /content/playlists/?page=36
# scraped page 36
# next href: /content/playlists/?page=37
# scraped page 37
# next href: /content/playlists/?page=38
# scraped page 38
# next href: /content/playlists/?page=39
# scraped page 39
# next href: /content/playlists/?page=40
# scraped page 40
# next href: /content/playlists/?page=41
# scraped page 41
# next href: /content/playlists/?page=42
# scraped page 42
# next href: /content/playlists/?page=43
# scraped page 43
# next href: /content/playlists/?page=44
# scraped page 44
# next href: /content/playlists/?page=45
# scraped page 45
# next href: /content/playlists/?page=46
# scraped page 46
# finished!
# 1095 playlists in total

# %%
playlists[20:25]
# Out:
# [{'title': '-',
#   'author': {'name': 'DJLeo',
#    'href': '/network/users/0d4df140-23aa-424e-a1dc-4e531a7ed4ab/'},
#   'href': '/content/playlists/6c0734dd-98e8-4f44-80fc-556c68ff32f4/',
#   'tags': ['New Music']},
#  {'title': 'Sweet Morning #1',
#   'author': {'name': 'blundetto',
#    'href': '/network/users/5fd28952-6bca-41c3-b295-f33a6ecf1d2d/'},
#   'href': '/content/playlists/0d6aabbe-8996-4295-9384-09baccd2606b/',
#   'tags': ['Eclectic', 'Flow', 'Smooth']},
#  {'title': 'Mikro #16',
#   'author': {'name': 'Restomas',
#    'href': '/network/users/9e82d32f-a49f-4395-8ba9-f06a1c7d438c/'},
#   'href': '/content/playlists/e6757d6f-5ad3-4b40-a784-55c285081e2e/',
#   'tags': ['corona']},
#  {'title': 'Sali! #16',
#   'author': {'name': 'Baxter',
#    'href': '/network/users/5be9a833-8338-43cc-b7d7-a4186b19c44d/'},
#   'href': '/content/playlists/c05af960-d17e-4f64-ad01-8ffac8cec886/',
#   'tags': ['Alternative',
#    'Chill',
#    'Easy ...ening',
#    'Jazz',
#    'Neo Soul',
#    'Soul']},
#  {'title': 'Mikro #15',
#   'author': {'name': 'Restomas',
#    'href': '/network/users/9e82d32f-a49f-4395-8ba9-f06a1c7d438c/'},
#   'href': '/content/playlists/6c2997bb-f17f-4630-9da5-405fde083f12/',
#   'tags': ['corona']}]

# %%
d_find_and_replace = {'Easy ...ening': 'Easy Listening'}
for playlist in playlists:
    tags = playlist['tags']
    for i, item in enumerate(tags):
        tags[i] = d_find_and_replace.get(item, item)
playlists[20:25]
# Out:
# [{'title': '-',
#   'author': {'name': 'DJLeo',
#    'href': '/network/users/0d4df140-23aa-424e-a1dc-4e531a7ed4ab/'},
#   'href': '/content/playlists/6c0734dd-98e8-4f44-80fc-556c68ff32f4/',
#   'tags': ['New Music']},
#  {'title': 'Sweet Morning #1',
#   'author': {'name': 'blundetto',
#    'href': '/network/users/5fd28952-6bca-41c3-b295-f33a6ecf1d2d/'},
#   'href': '/content/playlists/0d6aabbe-8996-4295-9384-09baccd2606b/',
#   'tags': ['Eclectic', 'Flow', 'Smooth']},
#  {'title': 'Mikro #16',
#   'author': {'name': 'Restomas',
#    'href': '/network/users/9e82d32f-a49f-4395-8ba9-f06a1c7d438c/'},
#   'href': '/content/playlists/e6757d6f-5ad3-4b40-a784-55c285081e2e/',
#   'tags': ['corona']},
#  {'title': 'Sali! #16',
#   'author': {'name': 'Baxter',
#    'href': '/network/users/5be9a833-8338-43cc-b7d7-a4186b19c44d/'},
#   'href': '/content/playlists/c05af960-d17e-4f64-ad01-8ffac8cec886/',
#   'tags': ['Alternative',
#    'Chill',
#    'Easy Listening',
#    'Jazz',
#    'Neo Soul',
#    'Soul']},
#  {'title': 'Mikro #15',
#   'author': {'name': 'Restomas',
#    'href': '/network/users/9e82d32f-a49f-4395-8ba9-f06a1c7d438c/'},
#   'href': '/content/playlists/6c2997bb-f17f-4630-9da5-405fde083f12/',
#   'tags': ['corona']}]

# %%
import json
import os
folder = 'data'
filename = f'openbroadcast-all_playlists_{utils.timestamp()}.json'
if not os.path.exists(folder):
    os.mkdir(folder)
with open(os.path.join(folder, filename), 'w', encoding='utf-8') as f:
    json.dump(playlists, f, ensure_ascii=False, indent=4)

# %%
import json
with open(os.path.join(folder, filename)) as f:
    playlists = json.load(f)
playlists[:5]
# Out:
# [{'title': 'Easter #8',
#   'author': {'name': 'Restomas',
#    'href': '/network/users/9e82d32f-a49f-4395-8ba9-f06a1c7d438c/'},
#   'href': '/content/playlists/eb8ced11-e7b9-4a9f-80ef-0f639fdfc583/',
#   'tags': ['Flow', 'Folk', 'Funk', 'Indie', 'Mellow', 'Pop']},
#  {'title': 'Easter #7',
#   'author': {'name': 'Restomas',
#    'href': '/network/users/9e82d32f-a49f-4395-8ba9-f06a1c7d438c/'},
#   'href': '/content/playlists/3319e56d-3e1c-4d1d-b9a4-0b01865f0021/',
#   'tags': ['Flow', 'Indie', 'Mellow', 'Pop']},
#  {'title': 'Ocean #10',
#   'author': {'name': 'Restomas',
#    'href': '/network/users/9e82d32f-a49f-4395-8ba9-f06a1c7d438c/'},
#   'href': '/content/playlists/edf34a36-1210-4f3f-9ab0-bf0f200d4eab/',
#   'tags': ['Electronic',
#    'Experimental',
#    'Field...rding',
#    'Jazz',
#    'Night',
#    'Sleep']},
#  {'title': 'Mikro #23',
#   'author': {'name': 'Restomas',
#    'href': '/network/users/9e82d32f-a49f-4395-8ba9-f06a1c7d438c/'},
#   'href': '/content/playlists/42f2fba5-8715-4e0c-bbc9-80b41993ad3b/',
#   'tags': ['corona']},
#  {'title': '-',
#   'author': {'name': 'Pat',
#    'href': '/network/users/5a9bc657-dd53-485e-a4b4-c8f32af354e5/'},
#   'href': '/content/playlists/27313549-b5f6-416b-8545-918a87b78997/',
#   'tags': ['Eclectic', 'Soul', 'World']}]

# %%
lists = [list for list in playlists 
         if (list['author']['name'] == 'blundetto') and ("Yard" in list['title'])]
lists
# Out:
# [{'title': 'Yard Tings #12',
#   'author': {'name': 'blundetto',
#    'href': '/network/users/5fd28952-6bca-41c3-b295-f33a6ecf1d2d/'},
#   'href': '/content/playlists/d651e8b6-e7b7-4cb1-866d-81c3108a729c/',
#   'tags': ['Reggae']},
#  {'title': 'Yard Tings #11',
#   'author': {'name': 'blundetto',
#    'href': '/network/users/5fd28952-6bca-41c3-b295-f33a6ecf1d2d/'},
#   'href': '/content/playlists/08bfab75-add8-4a1a-9aef-50bb937eb764/',
#   'tags': ['Flow', 'Jamaica', 'Reggae', 'Rocksteady']},
#  {'title': 'Yard Tings #10',
#   'author': {'name': 'blundetto',
#    'href': '/network/users/5fd28952-6bca-41c3-b295-f33a6ecf1d2d/'},
#   'href': '/content/playlists/a40e9961-82c6-4178-92c6-112093d09ae8/',
#   'tags': ['Flow', 'Jamaica', 'Reggae', 'Rocksteady']},
#  {'title': 'Yard Tings #9',
#   'author': {'name': 'blundetto',
#    'href': '/network/users/5fd28952-6bca-41c3-b295-f33a6ecf1d2d/'},
#   'href': '/content/playlists/01f8cfaa-4889-4ab2-812e-af387616a52e/',
#   'tags': ['Dub', 'Jamaica', 'Reggae', 'Roots']},
#  {'title': 'Yard Tings #8',
#   'author': {'name': 'blundetto',
#    'href': '/network/users/5fd28952-6bca-41c3-b295-f33a6ecf1d2d/'},
#   'href': '/content/playlists/405ee094-1e95-487d-b670-5d58340e2bbf/',
#   'tags': ["60's", "70's", "80's", 'Dub', 'Jamaica', 'Reggae', 'Roots']},
#  {'title': 'Yard Tings #7',
#   'author': {'name': 'blundetto',
#    'href': '/network/users/5fd28952-6bca-41c3-b295-f33a6ecf1d2d/'},
#   'href': '/content/playlists/34781e07-70f9-4d0c-ba53-0b54275a7060/',
#   'tags': ['Reggae']},
#  {'title': 'Yard Tings #5',
#   'author': {'name': 'blundetto',
#    'href': '/network/users/5fd28952-6bca-41c3-b295-f33a6ecf1d2d/'},
#   'href': '/content/playlists/64daefc1-c43b-4df2-94c2-478845d758ef/',
#   'tags': ['Dub', 'Jamaica', 'Reggae', 'Rocksteady', 'Soul']},
#  {'title': 'Yard Tings #4',
#   'author': {'name': 'blundetto',
#    'href': '/network/users/5fd28952-6bca-41c3-b295-f33a6ecf1d2d/'},
#   'href': '/content/playlists/a8d93cfb-0091-4fbe-b85c-52a8ee793f49/',
#   'tags': ['Jamaica', 'Reggae', 'Rocksteady', 'Soul']},
#  {'title': 'Yard Tings #6',
#   'author': {'name': 'blundetto',
#    'href': '/network/users/5fd28952-6bca-41c3-b295-f33a6ecf1d2d/'},
#   'href': '/content/playlists/c3d29353-2821-4d44-9bc4-b1f279aab03e/',
#   'tags': ['Flow', 'Heartbreaker', 'Night', 'Reggae', 'Rocksteady']},
#  {'title': 'Yard Tings #3',
#   'author': {'name': 'blundetto',
#    'href': '/network/users/5fd28952-6bca-41c3-b295-f33a6ecf1d2d/'},
#   'href': '/content/playlists/a16076f3-b0f0-4c01-b485-d8eedbd358dc/',
#   'tags': ['Dub', 'Reggae']},
#  {'title': 'Yard Tings #2',
#   'author': {'name': 'blundetto',
#    'href': '/network/users/5fd28952-6bca-41c3-b295-f33a6ecf1d2d/'},
#   'href': '/content/playlists/641769fb-9232-416c-b23f-44646953f226/',
#   'tags': ['Dub', 'Jamaica', 'Reggae']},
#  {'title': 'Yard Tings #1',
#   'author': {'name': 'blundetto',
#    'href': '/network/users/5fd28952-6bca-41c3-b295-f33a6ecf1d2d/'},
#   'href': '/content/playlists/f9ca5fd3-ae2f-4d0d-ad37-3d9dfea31d50/',
#   'tags': ['Reggae']}]

# %%
hrefs = [list['href'] for list in lists]
hrefs
# Out:
# ['/content/playlists/d651e8b6-e7b7-4cb1-866d-81c3108a729c/',
#  '/content/playlists/08bfab75-add8-4a1a-9aef-50bb937eb764/',
#  '/content/playlists/a40e9961-82c6-4178-92c6-112093d09ae8/',
#  '/content/playlists/01f8cfaa-4889-4ab2-812e-af387616a52e/',
#  '/content/playlists/405ee094-1e95-487d-b670-5d58340e2bbf/',
#  '/content/playlists/34781e07-70f9-4d0c-ba53-0b54275a7060/',
#  '/content/playlists/64daefc1-c43b-4df2-94c2-478845d758ef/',
#  '/content/playlists/a8d93cfb-0091-4fbe-b85c-52a8ee793f49/',
#  '/content/playlists/c3d29353-2821-4d44-9bc4-b1f279aab03e/',
#  '/content/playlists/a16076f3-b0f0-4c01-b485-d8eedbd358dc/',
#  '/content/playlists/641769fb-9232-416c-b23f-44646953f226/',
#  '/content/playlists/f9ca5fd3-ae2f-4d0d-ad37-3d9dfea31d50/']

# %%
tracks = []
for href in hrefs:
    URL = base_url + href
    response = requests.get(URL)
    if response.status_code == 200:
        print(f"scraped page {href}")
    else:
        print(f"error while scraping page {href}: {response}")
    soup = bs(response.content, 'html.parser')
    page_items = soup.find_all('div', class_='list_body_item c2')
    for item in page_items:
        title = item.li.a.contents[0].strip()
        artist = item.find_all('li')[1].a.text.strip()
        tracks.append({'title': title, 'artist': artist})
print(f"{len(tracks)} tracks")
# Out:
# scraped page /content/playlists/d651e8b6-e7b7-4cb1-866d-81c3108a729c/
# scraped page /content/playlists/08bfab75-add8-4a1a-9aef-50bb937eb764/
# scraped page /content/playlists/a40e9961-82c6-4178-92c6-112093d09ae8/
# scraped page /content/playlists/01f8cfaa-4889-4ab2-812e-af387616a52e/
# scraped page /content/playlists/405ee094-1e95-487d-b670-5d58340e2bbf/
# scraped page /content/playlists/34781e07-70f9-4d0c-ba53-0b54275a7060/
# scraped page /content/playlists/64daefc1-c43b-4df2-94c2-478845d758ef/
# scraped page /content/playlists/a8d93cfb-0091-4fbe-b85c-52a8ee793f49/
# scraped page /content/playlists/c3d29353-2821-4d44-9bc4-b1f279aab03e/
# scraped page /content/playlists/a16076f3-b0f0-4c01-b485-d8eedbd358dc/
# scraped page /content/playlists/641769fb-9232-416c-b23f-44646953f226/
# scraped page /content/playlists/f9ca5fd3-ae2f-4d0d-ad37-3d9dfea31d50/
# 291 tracks

# %%
tracks[:5]
# Out:
# [{'title': 'STATION-ID - Roar kurz', 'artist': 'Roland Widmer'},
#  {'title': 'The Look of Love', 'artist': 'Dennis Brown'},
#  {'title': "Alton's Official Daughter", 'artist': 'Alton Ellis'},
#  {'title': 'Satisfaction', 'artist': 'Carl Dawkins'},
#  {'title': 'STATION-ID - Andavoicepur', 'artist': 'Roland Widmer'}]

# %%
playlist = {'series': "Yard Things", 'author': "blundetto", 'tracks': tracks}
playlist
# Out:
# {'series': 'Yard Things',
#  'author': 'blundetto',
#  'tracks': [{'title': 'STATION-ID - Roar kurz', 'artist': 'Roland Widmer'},
#   {'title': 'The Look of Love', 'artist': 'Dennis Brown'},
#   {'title': "Alton's Official Daughter", 'artist': 'Alton Ellis'},
#   {'title': 'Satisfaction', 'artist': 'Carl Dawkins'},
#   {'title': 'STATION-ID - Andavoicepur', 'artist': 'Roland Widmer'},
#   {'title': 'Santic Rock', 'artist': 'Leonard Santic All Stars'},
#   {'title': 'Late at Night', 'artist': 'William Shakespeare'},
#   {'title': 'Problem #2', 'artist': 'Leonard Santic All Stars'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Got to Be Cool', 'artist': 'Wailing Souls'},
#   {'title': 'Gideons High', 'artist': 'Max Edwards'},
#   {'title': 'If You Ask Me', 'artist': 'Leon Dinero'},
#   {'title': 'Bandits', 'artist': 'Screechy Dan'},
#   {'title': 'STATION-ID - 123 Knock', 'artist': 'Roland Widmer'},
#   {'title': 'Get Together', 'artist': 'Carl Dawkins'},
#   {'title': "Ain't No Sunshine", 'artist': 'Ken Boothe'},
#   {'title': "It's a Shame", 'artist': 'Alton Ellis'},
#   {'title': 'Ten To One', 'artist': 'Cornell Campbell'},
#   {'title': 'STATION-ID - Roar kurz', 'artist': 'Roland Widmer'},
#   {'title': 'Push Harder', 'artist': 'Pensi'},
#   {'title': 'Who Is Mr Brown', 'artist': 'Bob Marley & The Wailers'},
#   {'title': 'Danger In Your Eyes', 'artist': 'Johnny Osbourne'},
#   {'title': "Burnin' Fire", 'artist': 'Carl Dawkins'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Why Did You Run Away?', 'artist': 'The Blenders'},
#   {'title': 'STATION-ID - Korken', 'artist': 'Roland Widmer'},
#   {'title': 'Better Must Come', 'artist': 'Delroy Wilson'},
#   {'title': 'Lambs Bread Collie', 'artist': 'Cedric "Im" Brooks'},
#   {'title': 'STATION-ID - Roar', 'artist': 'Roland Widmer'},
#   {'title': 'When the Lights Are Low', 'artist': 'Joya Landis'},
#   {'title': "I'm The One To Be Blamed", 'artist': 'John Holt'},
#   {'title': 'Creation', 'artist': 'Joe Higgs'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Worries (A Yard)', 'artist': 'The Versatiles'},
#   {'title': 'Black Society', 'artist': 'Ossie\xa0“Bongo”\xa0Hibbert'},
#   {'title': 'Sky Jack', 'artist': 'Bingi\xa0Kicks'},
#   {'title': 'Sky Jacking Version', 'artist': 'Leroy Sibbles'},
#   {'title': 'Dub with a View', 'artist': 'King Tubby'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Mr. President', 'artist': 'The\xa0Heptones'},
#   {'title': 'Dignity & Principle (version)', 'artist': 'Big Joe'},
#   {'title': 'You Just Got to Be in Love', 'artist': 'Boris Gardiner'},
#   {'title': 'STATION-ID - Wusch', 'artist': 'Roland Widmer'},
#   {'title': 'We People', 'artist': 'Nicky Thomas'},
#   {'title': 'You’ll Never Fin...r Love Like Mine', 'artist': 'John Holt'},
#   {'title': 'Do Your Thing', 'artist': 'Glen Adams'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'The Message', 'artist': 'Tinga Stewart'},
#   {'title': 'Thin Line Between Love And hate', 'artist': 'B.B. Seaton'},
#   {'title': 'Too Late To Turn Back Now', 'artist': 'Alton Ellis'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Pearls', 'artist': 'Alton Ellis'},
#   {'title': 'Youth Man (edit)', 'artist': 'Wayne\xa0Jarrett'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Youth Man (edit)', 'artist': 'Wayne\xa0Jarrett'},
#   {'title': 'Black Organ', 'artist': 'Jackie Mittoo'},
#   {'title': 'Happy Man', 'artist': 'The Gladiators'},
#   {'title': 'STATION-ID - Roar', 'artist': 'Roland Widmer'},
#   {'title': 'Mother and Child', 'artist': 'Fabian Cooke'},
#   {'title': 'Solomon', 'artist': 'Derrick Harriott'},
#   {'title': 'I Will Get Along Without You', 'artist': 'The Melodians'},
#   {'title': 'Jah a Love You', 'artist': 'Sugar Minott'},
#   {'title': 'STATION-ID - Wusch', 'artist': 'Roland Widmer'},
#   {'title': 'Black Out', 'artist': 'The Hardy Boys'},
#   {'title': 'Dreader Than Dread', 'artist': 'Honey Boy Martin'},
#   {'title': 'Shocking Love', 'artist': 'The Federals'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Little Things', 'artist': 'Hemsley Morris'},
#   {'title': 'Do I worry', 'artist': 'Scotty'},
#   {'title': 'Trying to Conquer Me', 'artist': 'Delroy Wilson'},
#   {'title': 'No Place Like Home', 'artist': 'Desmond Dekker'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Soul Fire', 'artist': 'Lee Perry'},
#   {'title': 'Dreada Version', 'artist': 'King Tubby'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'STATION-ID - Doppeler FRO2', 'artist': 'Roland Widmer'},
#   {'title': 'In a Strange Land', 'artist': 'Native'},
#   {'title': 'Real Gone Crazy Dub', 'artist': 'King Tubby'},
#   {'title': 'Cloning Process', 'artist': 'Scientist'},
#   {'title': 'Piano Country', 'artist': 'Native'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Piano Country', 'artist': 'Native'},
#   {'title': 'Lime Key Rock', 'artist': 'Joe\xa0Gibbs'},
#   {'title': 'Concentration Version 3', 'artist': 'The Crystalites'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Great God Over in Zion', 'artist': 'Boston Jack'},
#   {'title': 'Grooving Kgn. 12', 'artist': 'Bob Marley & The Wailers'},
#   {'title': 'Garvey Dub', 'artist': 'The Revolutionaries'},
#   {'title': 'STATION-ID - Wusch', 'artist': 'Roland Widmer'},
#   {'title': 'Run For Cover', 'artist': 'Bob Marley & The Wailers'},
#   {'title': 'Words of My Mouth', 'artist': 'The Gatherers'},
#   {'title': 'When I Fall in Love', 'artist': 'Ken Boothe'},
#   {'title': "You're Gonna Need Me", 'artist': 'Errol Dunkley'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Forward Jah Jah Children', 'artist': 'Inner Circle'},
#   {'title': 'Pack Up', 'artist': 'Wailing Souls'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Only a Smile', 'artist': 'The Paragons'},
#   {'title': 'Fusing & Fighting', 'artist': 'Bob Marley & The Wailers'},
#   {'title': 'STATION-ID - Doppeler FRO2', 'artist': 'Roland Widmer'},
#   {'title': 'I Have Been In Love', 'artist': 'Delroy Wilson'},
#   {'title': 'Ooh La La Dub', 'artist': 'Lee\xa0Perry'},
#   {'title': 'Joy in the Morning', 'artist': 'The\xa0Gaylads'},
#   {'title': 'Darker Than Blue', 'artist': 'Lloyd Charmers'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Who Colt the Game', 'artist': 'Bob Marley & The Wailers'},
#   {'title': 'Who Colt the Game (dub version)', 'artist': 'The Upsetters'},
#   {'title': 'Love Makes The World Go Round', 'artist': 'Johnny\xa0Osbourne'},
#   {'title': 'Cool Breeze', 'artist': 'Big Youth'},
#   {'title': 'STATION-ID - Doppeler FRO2', 'artist': 'Roland Widmer'},
#   {'title': 'Contemplating Mind', 'artist': 'Barrington Spence'},
#   {'title': 'Love Won’t Come Easy', 'artist': 'The Heptones'},
#   {'title': 'Easy Take It Easy', 'artist': 'Dennis Brown'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'I Who Have Nothing', 'artist': 'Jah Skerta'},
#   {'title': 'High Times', 'artist': 'Roots Underground'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Supernatural Thing', 'artist': 'Richard Ace'},
#   {'title': 'Have I Sinned', 'artist': 'Lloyd Charmers'},
#   {'title': 'Lorna Banana', 'artist': 'Dennis\xa0Alcapone'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Love Is The Key', 'artist': 'The Viceroys'},
#   {'title': 'Dread All The Way', 'artist': 'Rod Taylor'},
#   {'title': 'Rock a Dub', 'artist': 'King\xa0Tubby'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Ghetto Skank', 'artist': 'Joe\xa0Gibbs'},
#   {'title': 'STATION-ID - Wusch', 'artist': 'Roland Widmer'},
#   {'title': "It It Because I'm Black?", 'artist': 'Ken Boothe'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Mystic Chant', 'artist': 'Garnett Silk'},
#   {'title': 'STATION-ID - Wusch', 'artist': 'Roland Widmer'},
#   {'title': 'Free for All', 'artist': 'Tafari All Stars'},
#   {'title': 'Soul Drums', 'artist': 'Count\xa0Ossie'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Breezing', 'artist': 'Willie Lindo'},
#   {'title': 'South African Reggae', 'artist': 'Cedric "Im" Brooks'},
#   {'title': 'Downpressor', 'artist': 'Bob Marley & The Wailers'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'A Closer Dub', 'artist': 'King Tubby'},
#   {'title': 'Dance Of The Knights Dub', 'artist': 'Mato'},
#   {'title': 'Popcorn Funky Reggae', 'artist': 'Rita Alston'},
#   {'title': 'STATION-ID - Doppeler FRO2', 'artist': 'Roland Widmer'},
#   {'title': 'Ordinary Man', 'artist': 'Lloyd Parks'},
#   {'title': 'Martial Law', 'artist': 'Joe Gibbs'},
#   {'title': 'Burning Fire', 'artist': 'Jr. Thomas & The Volcanos'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Satisfy My Soul Jah Jah', 'artist': 'Bob Marley & The Wailers'},
#   {'title': 'Satisfy Version', 'artist': 'Bob Marley & The Wailers'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Give a Little Love', 'artist': 'Johnny Osbourne'},
#   {'title': 'My Mission Is Impossible (1981 cut)', 'artist': 'The Viceroys'},
#   {'title': 'Pressure', 'artist': 'Garnett Silk'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'The General', 'artist': 'Jahdan Blakkamoore'},
#   {'title': 'STATION-ID - Doppeler FRO2', 'artist': 'Roland Widmer'},
#   {'title': 'Silver Dollar', 'artist': 'Tommy\xa0McCook'},
#   {'title': 'Stop', 'artist': 'Jr. Thomas & The Volcanos'},
#   {'title': 'STATION-ID - Wusch', 'artist': 'Roland Widmer'},
#   {'title': 'African Herbsman', 'artist': 'Bob Marley & The Wailers'},
#   {'title': 'Send Me That Love', 'artist': 'Bob Marley & The Wailers'},
#   {'title': 'We Need Love', 'artist': 'Johnny Osbourne'},
#   {'title': 'Truth and Rights', 'artist': 'Johnny Osbourne'},
#   {'title': "I'm a Free Man", 'artist': 'Freddie McKay'},
#   {'title': 'STATION-ID - Andavoicepur', 'artist': 'Roland Widmer'},
#   {'title': 'Send a Moses', 'artist': 'Barrington Levy'},
#   {'title': 'Sensimella', 'artist': 'Barrington Levy'},
#   {'title': 'Embargo', 'artist': 'Joe Gibbs'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Kings Highway ( Version )', 'artist': 'Soul Syndicate'},
#   {'title': 'Kings Highway', 'artist': 'Soul Syndicate'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Days Chasing Days', 'artist': 'The Congos'},
#   {'title': "Don't Blame on I", 'artist': 'The Congos'},
#   {'title': 'Dancing Version', 'artist': 'King Tubby'},
#   {'title': 'Love o the Jah Jah Children', 'artist': 'The G.G. All Stars'},
#   {'title': 'Iyahta', 'artist': 'King Tubby'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'The Exit', 'artist': 'Dennis Brown'},
#   {'title': 'Version', 'artist': 'Super Power All Stars'},
#   {'title': 'STATION-ID - Wusch', 'artist': 'Roland Widmer'},
#   {'title': 'Why Am I Treated So Bad?', 'artist': 'Lyn Taitt & The Jets'},
#   {'title': 'Riding High on a Windy Day', 'artist': 'The Paragons'},
#   {'title': 'If I Could Rule The World', 'artist': 'Alton Ellis'},
#   {'title': 'STATION-ID - Wusch', 'artist': 'Roland Widmer'},
#   {'title': 'Our Day Will Come', 'artist': 'The Heptones'},
#   {'title': 'Morning Sun', 'artist': 'Al Barry'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Can I Change My Mind', 'artist': 'Delroy Wilson'},
#   {'title': 'Jah Jah Me Horn Yah', 'artist': 'Cornell Campbell'},
#   {'title': 'Got to Get Away', 'artist': 'The Paragons'},
#   {'title': 'Rise and Fall', 'artist': 'Alton Ellis'},
#   {'title': 'STATION-ID - Doppeler FRO2', 'artist': 'Roland Widmer'},
#   {'title': 'You Hurt My Soul', 'artist': 'Joe Higgs'},
#   {'title': 'Born To Fly', 'artist': 'Courtney John'},
#   {'title': 'Gideons High', 'artist': 'Max Edwards'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': "It It Because I'm Black?", 'artist': 'Ken Boothe'},
#   {'title': 'Have A Little Faith', 'artist': 'Blundetto'},
#   {'title': 'Uncle Joe', 'artist': 'Gregory Isaacs'},
#   {'title': 'Party In the Slum', 'artist': 'Gregory Isaacs'},
#   {'title': 'STATION-ID - Andavoicepur', 'artist': 'Roland Widmer'},
#   {'title': 'West Bound D Train', 'artist': 'Lloyd Barnes'},
#   {'title': 'Jah Light', 'artist': 'Love Joys'},
#   {'title': 'Stay on Dub', 'artist': 'African Roots Act 3'},
#   {'title': 'STATION-ID - Can I begin', 'artist': 'Roland Widmer'},
#   {'title': 'Libra Dub', 'artist': 'Dub Specialist'},
#   {'title': 'What A Disaster', 'artist': 'Junior Brown'},
#   {'title': 'STATION-ID - Wusch', 'artist': 'Roland Widmer'},
#   {'title': 'Moonlight Lover', 'artist': 'Joya Landis'},
#   {'title': 'My Best Girl', 'artist': 'Dave & Ansel Collins'},
#   {'title': 'STATION-ID - Andavoicepur', 'artist': 'Roland Widmer'},
#   {'title': 'My Baby Still Loves Me', 'artist': 'Joe Higgs'},
#   {'title': 'Be Thankful', 'artist': 'Donovan Carlos'},
#   {'title': 'Lonely Soldier', 'artist': 'Gregory Isaacs'},
#   {'title': "Black Man's Worl... Man, White Man)", 'artist': 'Alton Ellis'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Gideons High', 'artist': 'Max Edwards'},
#   {'title': 'Ixes', 'artist': 'Max Edwards'},
#   {'title': 'STATION-ID - Doppeler FRO2', 'artist': 'Roland Widmer'},
#   {'title': 'Worries in the Dance', 'artist': 'Frankie Paul'},
#   {'title': 'Where The Man Comes From', 'artist': 'Mr. Williamz'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Declaration of Dub', 'artist': 'King Tubby'},
#   {'title': 'Silver Bullet', 'artist': 'The Observers'},
#   {'title': 'Prediction', 'artist': 'Steel Pulse'},
#   {'title': '12.00 - 13.00 PO...pfeifferclosermx', 'artist': 'Roland Widmer'},
#   {'title': 'Uptown Top Ranking', 'artist': 'Althea & Donna'},
#   {'title': 'Agola Crisis', 'artist': 'Joe\xa0Gibbs'},
#   {'title': "I'm Still In Love With You", 'artist': 'Marcia Aitken'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': "I'm Still In Love", 'artist': 'Lion\xa0Babe'},
#   {'title': 'STATION-ID - Wusch', 'artist': 'Roland Widmer'},
#   {'title': 'East Of (Arrows Hi-Fi)', 'artist': 'King Tubby'},
#   {'title': 'Work', 'artist': 'The Wailers'},
#   {'title': 'Ten Commandments', 'artist': 'Joe Gibbs'},
#   {'title': 'The Exit', 'artist': 'Dennis Brown'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Red Shift', 'artist': 'Scientist'},
#   {'title': 'Song of Blood', 'artist': 'Linton Kwesi Johnson'},
#   {'title': 'Shocking Dub', 'artist': 'Linton Kwesi Johnson'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Last Broken Dub', 'artist': 'Blundetto'},
#   {'title': 'One Step Dub', 'artist': 'The Upsetters'},
#   {'title': 'Dub to the Rescue', 'artist': 'King Tubby'},
#   {'title': 'STATION-ID - Fro', 'artist': 'Roland Widmer'},
#   {'title': 'I Trim the Barber', 'artist': 'King Tubby'},
#   {'title': 'You Rest on My Mind', 'artist': 'Naggo Morris'},
#   {'title': 'You and I', 'artist': 'Wayne Jarrett'},
#   {'title': 'Round 6', 'artist': 'Prince Jammy'},
#   {'title': 'STATION-ID - Wusch', 'artist': 'Roland Widmer'},
#   {'title': 'Dematerialise', 'artist': 'Scientist'},
#   {'title': 'A Step Before Hell', 'artist': 'Pablo Moses'},
#   {'title': 'Kings Of Dub', 'artist': 'Joe Gibbs'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': 'Dub Revolution, Part 1', 'artist': 'Lee Perry'},
#   {'title': 'Straight to the Boy Niney Head', 'artist': 'King Tubby'},
#   {'title': 'STATION-ID - Bserrusconi', 'artist': 'Roland Widmer'},
#   {'title': 'African Woman (version)', 'artist': 'Winston Fergus'},
#   {'title': "See a Man's Face", 'artist': 'Horace Andy'},
#   {'title': 'Oboe', 'artist': 'Jackie Mittoo'},
#   {'title': 'STATION-ID - Cutter', 'artist': 'Roland Widmer'},
#   {'title': 'It Dread Inna Inglan', 'artist': 'Linton Kwesi Johnson'},
#   {'title': 'African Anthem Dread All The Way', 'artist': 'Mikey Dread'},
#   {'title': 'Beam Down', 'artist': 'Scientist'},
#   {'title': 'STATION-ID - Drop Box', 'artist': 'Roland Widmer'},
#   {'title': "Don't Blame on I", 'artist': 'The Congos'},
#   {'title': 'Keep on Moving (dub) (original mix)',
#    'artist': 'Bob Marley & The Wailers'},
#   {'title': 'STATION-ID - Open Can short', 'artist': 'Roland Widmer'},
#   {'title': 'Mellow Mood (Jahno dub)', 'artist': 'Soul Sugar'},
#   {'title': 'Spying Glass', 'artist': 'Horace Andy'},
#   {'title': 'Guided Missile', 'artist': 'The Wailers'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': 'STATION-ID - Kla... Einstimmer lang', 'artist': 'Roland Widmer'},
#   {'title': 'Run Come Rally', 'artist': 'Dadawah'},
#   {'title': 'Rats in the Ghetto', 'artist': 'Boris Gardiner'},
#   {'title': 'Bumps in the Night', 'artist': 'Jr. Thomas & The Volcanos'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Man Next Door', 'artist': 'John Holt'},
#   {'title': 'Rock Me', 'artist': 'The Monks'},
#   {'title': 'African Anthem Dread All The Way', 'artist': 'Mikey Dread'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Someone', 'artist': 'Alton Ellis'},
#   {'title': 'Kampala', 'artist': 'Harold Butler'},
#   {'title': 'How Long Do I Ha...for You? (vocal)', 'artist': 'Sharon Jones'},
#   {'title': 'STATION-ID - Fro', 'artist': 'Roland Widmer'},
#   {'title': 'Tenor on Call', 'artist': 'Tommy McCook'},
#   {'title': 'Someone', 'artist': 'Alton Ellis'},
#   {'title': 'Drum Song', 'artist': 'Jackie Mittoo'},
#   {'title': 'STATION-ID - Wusch', 'artist': 'Roland Widmer'},
#   {'title': 'Fu Man Chu', 'artist': 'Desmond Dekker'},
#   {'title': 'Shooter Dub', 'artist': 'King Tubby'}]}

# %%
playlist['series']
# Out:
# 'Yard Things'

# %%
import json
import os
folder = 'data'
filename = f'openbroadcast-YardThings_{utils.timestamp()}.json'
if not os.path.exists(folder):
    os.mkdir(folder)
with open(os.path.join(folder, filename), 'w', encoding='utf-8') as f:
    json.dump(playlist, f, ensure_ascii=False, indent=4)
