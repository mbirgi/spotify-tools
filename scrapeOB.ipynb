# %% [markdown]
# ### Scrapes playlists from Open Broadcast Radio

# %%
import pprint
import requests
from bs4 import BeautifulSoup as bs

pp = pprint.PrettyPrinter(indent=4)

# %% [markdown]
# #### scrape all playlists:

# %%
playlists = []
base_url = "https://www.openbroadcast.org"
href = "/content/playlists/?page=1"
while True:
    url = base_url + href
    response = requests.get(url)
    if response.status_code == 200:
        soup = bs(response.content)
        page_items = soup.find_all('div', class_='list-item')
#         print(f"1st page_item: {page_items[0]}")
        page_playlists = []
        for item in page_items:
            all_links = item.find_all('a')
            title = all_links[0]['title']
            href = all_links[0]['href']
            author = {
                'name': all_links[1].text.strip(),
                'href': all_links[1]['href']
            }
            tags = [span.text.strip() for span in item.find_all('span', class_='tag')]
            playlist = {
                'title': title,
                'href': href,
                'author': author,
                'tags': tags
            }
            page_playlists.append(playlist)
        playlists.extend(page_playlists)
#         print(playlists[0])
    else:
        print(f"error while scraping page {page}")
        print(f"    error code: {response.status_code}")
        print(f"    URL: {url}")
        continue
    pagination = soup.find('div', class_='pagination')
    current_page = pagination.find('span', class_='current page').text
    print(f"scraped page {current_page}")
    if pagination.find('span', class_='disabled next'):
        print("finished!")
        print(f"{len(playlists)} playlists in total")
        break
    href = pagination.find('a', class_='next')['href']
    print(f"next href: {href}")
    if current_page == "100":
        print("failsafe!")
        break
# Out:
# scraped page 1
# next href: /content/playlists/?page=2
# scraped page 2
# next href: /content/playlists/?page=3
# scraped page 3
# next href: /content/playlists/?page=4
# scraped page 4
# next href: /content/playlists/?page=5
# scraped page 5
# next href: /content/playlists/?page=6
# scraped page 6
# next href: /content/playlists/?page=7
# scraped page 7
# next href: /content/playlists/?page=8
# scraped page 8
# next href: /content/playlists/?page=9
# scraped page 9
# next href: /content/playlists/?page=10
# scraped page 10
# next href: /content/playlists/?page=11
# scraped page 11
# next href: /content/playlists/?page=12
# scraped page 12
# next href: /content/playlists/?page=13
# scraped page 13
# next href: /content/playlists/?page=14
# scraped page 14
# next href: /content/playlists/?page=15
# scraped page 15
# next href: /content/playlists/?page=16
# scraped page 16
# next href: /content/playlists/?page=17
# scraped page 17
# next href: /content/playlists/?page=18
# scraped page 18
# next href: /content/playlists/?page=19
# scraped page 19
# next href: /content/playlists/?page=20
# scraped page 20
# next href: /content/playlists/?page=21
# scraped page 21
# next href: /content/playlists/?page=22
# scraped page 22
# next href: /content/playlists/?page=23
# scraped page 23
# next href: /content/playlists/?page=24
# scraped page 24
# next href: /content/playlists/?page=25
# scraped page 25
# next href: /content/playlists/?page=26
# scraped page 26
# next href: /content/playlists/?page=27
# scraped page 27
# next href: /content/playlists/?page=28
# scraped page 28
# next href: /content/playlists/?page=29
# scraped page 29
# next href: /content/playlists/?page=30
# scraped page 30
# next href: /content/playlists/?page=31
# scraped page 31
# next href: /content/playlists/?page=32
# scraped page 32
# next href: /content/playlists/?page=33
# scraped page 33
# next href: /content/playlists/?page=34
# scraped page 34
# next href: /content/playlists/?page=35
# scraped page 35
# next href: /content/playlists/?page=36
# scraped page 36
# next href: /content/playlists/?page=37
# scraped page 37
# next href: /content/playlists/?page=38
# scraped page 38
# next href: /content/playlists/?page=39
# scraped page 39
# next href: /content/playlists/?page=40
# scraped page 40
# next href: /content/playlists/?page=41
# scraped page 41
# next href: /content/playlists/?page=42
# scraped page 42
# next href: /content/playlists/?page=43
# scraped page 43
# next href: /content/playlists/?page=44
# scraped page 44
# next href: /content/playlists/?page=45
# scraped page 45
# next href: /content/playlists/?page=46
# scraped page 46
# next href: /content/playlists/?page=47
# scraped page 47
# finished!
# 1112 playlists in total

# %%
playlists[20:25]
# Out:
# [{'title': 'Ocean',
#   'href': '/content/playlists/edf34a36-1210-4f3f-9ab0-bf0f200d4eab/',
#   'author': {'name': 'Restomas',
#    'href': '/network/users/9e82d32f-a49f-4395-8ba9-f06a1c7d438c/'},
#   'tags': ['Electronic', 'Experimental', 'Field...rding', 'Jazz']},
#  {'title': 'Ajele - on a Weekend too ;-)',
#   'href': '/content/playlists/27313549-b5f6-416b-8545-918a87b78997/',
#   'author': {'name': 'Pat',
#    'href': '/network/users/5a9bc657-dd53-485e-a4b4-c8f32af354e5/'},
#   'tags': ['Eclectic', 'Soul', 'World']},
#  {'title': 'Charriza',
#   'href': '/content/playlists/83c43e12-7280-4797-a65a-295737d8579d/',
#   'author': {'name': 'Pat',
#    'href': '/network/users/5a9bc657-dd53-485e-a4b4-c8f32af354e5/'},
#   'tags': ['Alternative', 'Flow', 'Mellow', 'Sleep']},
#  {'title': 'Afternoon Bunny',
#   'href': '/content/playlists/7eef7959-5f88-4105-992e-a0223514ac7d/',
#   'author': {'name': 'Baxter',
#    'href': '/network/users/5be9a833-8338-43cc-b7d7-a4186b19c44d/'},
#   'tags': ['Alternative', 'Funk', 'Neo Soul', 'Reggae']},
#  {'title': 'NDR Info informiert über Coronavirus',
#   'href': '/content/playlists/9c1a7033-2bbc-4175-8f36-9537699ea07f/',
#   'author': {'name': 'Restomas',
#    'href': '/network/users/9e82d32f-a49f-4395-8ba9-f06a1c7d438c/'},
#   'tags': ['corona']}]

# %%
d_find_and_replace = {'Easy ...ening': 'Easy Listening'}
for playlist in playlists:
    tags = playlist['tags']
    for i, item in enumerate(tags):
        tags[i] = d_find_and_replace.get(item, item)
playlists[20:25]
# Out:
# [{'title': 'Ocean',
#   'href': '/content/playlists/edf34a36-1210-4f3f-9ab0-bf0f200d4eab/',
#   'author': {'name': 'Restomas',
#    'href': '/network/users/9e82d32f-a49f-4395-8ba9-f06a1c7d438c/'},
#   'tags': ['Electronic', 'Experimental', 'Field...rding', 'Jazz']},
#  {'title': 'Ajele - on a Weekend too ;-)',
#   'href': '/content/playlists/27313549-b5f6-416b-8545-918a87b78997/',
#   'author': {'name': 'Pat',
#    'href': '/network/users/5a9bc657-dd53-485e-a4b4-c8f32af354e5/'},
#   'tags': ['Eclectic', 'Soul', 'World']},
#  {'title': 'Charriza',
#   'href': '/content/playlists/83c43e12-7280-4797-a65a-295737d8579d/',
#   'author': {'name': 'Pat',
#    'href': '/network/users/5a9bc657-dd53-485e-a4b4-c8f32af354e5/'},
#   'tags': ['Alternative', 'Flow', 'Mellow', 'Sleep']},
#  {'title': 'Afternoon Bunny',
#   'href': '/content/playlists/7eef7959-5f88-4105-992e-a0223514ac7d/',
#   'author': {'name': 'Baxter',
#    'href': '/network/users/5be9a833-8338-43cc-b7d7-a4186b19c44d/'},
#   'tags': ['Alternative', 'Funk', 'Neo Soul', 'Reggae']},
#  {'title': 'NDR Info informiert über Coronavirus',
#   'href': '/content/playlists/9c1a7033-2bbc-4175-8f36-9537699ea07f/',
#   'author': {'name': 'Restomas',
#    'href': '/network/users/9e82d32f-a49f-4395-8ba9-f06a1c7d438c/'},
#   'tags': ['corona']}]

# %%
import json
import os
import utils
folder = 'data'
filename = f'openbroadcast-all_playlists_{utils.timestamp()}.json'
if not os.path.exists(folder):
    os.mkdir(folder)
with open(os.path.join(folder, filename), 'w', encoding='utf-8') as f:
    json.dump(playlists, f, ensure_ascii=False, indent=4)

# %%
import json
import os
folder = 'data'
filename = f'openbroadcast-all_playlists_2020-04-23-17-34-22.json'
with open(os.path.join(folder, filename)) as f:
    playlists = json.load(f)
playlists[:5]
# Out:
# [{'title': 'Sun Even',
#   'href': '/content/playlists/fb243c57-8f9d-46f8-a688-3c9ddb1fb4e4/',
#   'author': {'name': 'Pat',
#    'href': '/network/users/5a9bc657-dd53-485e-a4b4-c8f32af354e5/'},
#   'tags': ['Experimental', 'Jazz', 'Psychedelic', 'Sleep']},
#  {'title': 'NDR Info informiert über Coronavirus',
#   'href': '/content/playlists/b32f009a-e03a-4e91-bf57-13707ecf986a/',
#   'author': {'name': 'Restomas',
#    'href': '/network/users/9e82d32f-a49f-4395-8ba9-f06a1c7d438c/'},
#   'tags': ['corona']},
#  {'title': 'Good Morning Fifteen',
#   'href': '/content/playlists/706606ee-a927-45f5-82a0-831f71036858/',
#   'author': {'name': 'Baxter',
#    'href': '/network/users/5be9a833-8338-43cc-b7d7-a4186b19c44d/'},
#   'tags': ['Alternative', 'Conte...y R&B', 'Easy Listening', 'Hip Hop']},
#  {'title': 'Sleeper',
#   'href': '/content/playlists/51c12665-9315-4094-ba82-fa0418775167/',
#   'author': {'name': 'Pat',
#    'href': '/network/users/5a9bc657-dd53-485e-a4b4-c8f32af354e5/'},
#   'tags': ['Ambient', 'Electronic', 'Jazz', 'Night']},
#  {'title': 'dskfnf',
#   'href': '/content/playlists/ac7f169e-3709-41da-ae20-fa2e3b3fcd57/',
#   'author': {'name': 'OBPLibrary',
#    'href': '/network/users/1b427ff1-692d-408d-a98c-7580d7c7d516/'},
#   'tags': []}]

# %%
author = 'Restomas'
series = "Crossfader"
lists = [list for list in playlists 
         if (list['author']['name'] == author) and (series in list['title'])]
[list['title'] for list in lists if list['title'] != 'NDR Info informiert über Coronavirus']
# Out:
# ['Crossfader',
#  'Crossfader',
#  'Crossfader',
#  'Crossfader',
#  'Crossfader',
#  'Crossfader',
#  'Crossfader',
#  'Crossfader',
#  'Crossfader',
#  'Crossfader',
#  'Crossfader',
#  'Crossfader',
#  'Crossfader',
#  'Crossfader ',
#  'Crossfader',
#  'Crossfader',
#  'Crossfader',
#  'Crossfader',
#  'Crossfader',
#  'Crossfader 13',
#  'Crossfader',
#  'Crossfader',
#  'Crossfader',
#  'Crossfader',
#  'Crossfader',
#  'Crossfader',
#  'Crossfader',
#  'Crossfader',
#  'Crossfader']

# %%
hrefs = [list['href'] for list in lists]
hrefs
# Out:
# ['/content/playlists/eb8ced11-e7b9-4a9f-80ef-0f639fdfc583/',
#  '/content/playlists/3319e56d-3e1c-4d1d-b9a4-0b01865f0021/',
#  '/content/playlists/eafd99dd-dd08-43a2-ab0e-b29c4d42323c/',
#  '/content/playlists/a940b93e-a66b-43aa-a83b-09bdb7e359f2/',
#  '/content/playlists/9bacb7c7-1be1-488c-8bb7-e663c24ec291/',
#  '/content/playlists/26bb8445-c25b-4973-b85e-865a4de36084/',
#  '/content/playlists/6f59e0a6-e106-499d-9da5-558a7e7805cf/',
#  '/content/playlists/a2dabbdb-dcde-4adc-88c8-ca016d62e12f/',
#  '/content/playlists/f40c1443-3560-45b4-80a9-33a0944a656a/',
#  '/content/playlists/b6f7386a-8b50-4df8-879f-953cdbdd0bc0/',
#  '/content/playlists/3a9d98ef-a25f-4f02-a4b7-6035ba8f209a/',
#  '/content/playlists/919726a9-ebb7-4e28-b497-bfe6555e972a/',
#  '/content/playlists/082be01d-ad91-439c-9062-8bdfd3a77b66/',
#  '/content/playlists/ab0151cb-fe81-4b24-b2e6-0ffdd44939c1/',
#  '/content/playlists/bd3afd53-8fea-429a-8c92-937f6fda6538/',
#  '/content/playlists/ca869ce3-5d18-45f6-bb9a-13f790335834/',
#  '/content/playlists/7dbe4345-c19c-46b9-b79f-ec3ff27da816/',
#  '/content/playlists/4a45b8ef-a5b8-49e9-bdbe-321609520be2/',
#  '/content/playlists/53280a13-8cc0-453d-a7c6-d7e498e97a94/',
#  '/content/playlists/b35d0792-11f1-4379-bf7f-0cec85ef5df1/',
#  '/content/playlists/02b812aa-9395-4010-a881-b486933133ab/',
#  '/content/playlists/3e4910bd-7387-4a51-ae17-8809efc93999/',
#  '/content/playlists/51005d96-50f5-47c6-9a94-aabfc352962a/',
#  '/content/playlists/53b8166f-2538-494d-a138-5d6ca42cc0ef/',
#  '/content/playlists/01451aa2-d8f7-4075-81c7-dfabbaed7447/',
#  '/content/playlists/e7b56b6c-45c1-4c69-85e5-7a48e13556bf/',
#  '/content/playlists/58b2b8c4-74eb-4f63-baec-000245cd5b40/',
#  '/content/playlists/9cbc89e4-5ae0-42e0-883c-32a4136450a2/',
#  '/content/playlists/48134c40-d5a2-4fab-a16b-d8036600a9fd/']

# %%
import requests
from bs4 import BeautifulSoup as bs
base_url = "https://www.openbroadcast.org"
tracks = []
for href in hrefs:
    URL = base_url + href
    response = requests.get(URL)
    if response.status_code == 200:
        print(f"scraped page {href}")
    else:
        print(f"error while scraping page {href}: {response}")
    soup = bs(response.content, 'html.parser')
    page_items = soup.find_all('div', class_='list_body_item c2')
    for item in page_items:
        title = item.li.a.contents[0].strip()
        artist = item.find_all('li')[1].a.text.strip()
        tracks.append({'title': title, 'artist': artist})
print(f"{len(tracks)} tracks")
# Out:
# scraped page /content/playlists/eb8ced11-e7b9-4a9f-80ef-0f639fdfc583/
# scraped page /content/playlists/3319e56d-3e1c-4d1d-b9a4-0b01865f0021/
# scraped page /content/playlists/eafd99dd-dd08-43a2-ab0e-b29c4d42323c/
# scraped page /content/playlists/a940b93e-a66b-43aa-a83b-09bdb7e359f2/
# scraped page /content/playlists/9bacb7c7-1be1-488c-8bb7-e663c24ec291/
# scraped page /content/playlists/26bb8445-c25b-4973-b85e-865a4de36084/
# scraped page /content/playlists/6f59e0a6-e106-499d-9da5-558a7e7805cf/
# scraped page /content/playlists/a2dabbdb-dcde-4adc-88c8-ca016d62e12f/
# scraped page /content/playlists/f40c1443-3560-45b4-80a9-33a0944a656a/
# scraped page /content/playlists/b6f7386a-8b50-4df8-879f-953cdbdd0bc0/
# scraped page /content/playlists/3a9d98ef-a25f-4f02-a4b7-6035ba8f209a/
# scraped page /content/playlists/919726a9-ebb7-4e28-b497-bfe6555e972a/
# scraped page /content/playlists/082be01d-ad91-439c-9062-8bdfd3a77b66/
# scraped page /content/playlists/ab0151cb-fe81-4b24-b2e6-0ffdd44939c1/
# scraped page /content/playlists/bd3afd53-8fea-429a-8c92-937f6fda6538/
# scraped page /content/playlists/ca869ce3-5d18-45f6-bb9a-13f790335834/
# scraped page /content/playlists/7dbe4345-c19c-46b9-b79f-ec3ff27da816/
# scraped page /content/playlists/4a45b8ef-a5b8-49e9-bdbe-321609520be2/
# scraped page /content/playlists/53280a13-8cc0-453d-a7c6-d7e498e97a94/
# scraped page /content/playlists/b35d0792-11f1-4379-bf7f-0cec85ef5df1/
# scraped page /content/playlists/02b812aa-9395-4010-a881-b486933133ab/
# scraped page /content/playlists/3e4910bd-7387-4a51-ae17-8809efc93999/
# scraped page /content/playlists/51005d96-50f5-47c6-9a94-aabfc352962a/
# scraped page /content/playlists/53b8166f-2538-494d-a138-5d6ca42cc0ef/
# scraped page /content/playlists/01451aa2-d8f7-4075-81c7-dfabbaed7447/
# scraped page /content/playlists/e7b56b6c-45c1-4c69-85e5-7a48e13556bf/
# scraped page /content/playlists/58b2b8c4-74eb-4f63-baec-000245cd5b40/
# scraped page /content/playlists/9cbc89e4-5ae0-42e0-883c-32a4136450a2/
# scraped page /content/playlists/48134c40-d5a2-4fab-a16b-d8036600a9fd/
# 914 tracks

# %%
tracks[:5]
# Out:
# [{'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#  {'title': 'Wasting My Time', 'artist': 'Harry Nilsson'},
#  {'title': 'Working for the Man', 'artist': 'PJ Harvey'},
#  {'title': 'Angeles', 'artist': 'Elliott Smith'},
#  {'title': "Don't Be Cruel", 'artist': 'Billy Swan'}]

# %%
playlist = {'series': series, 'author': author, 'tracks': tracks}
playlist
# Out:
# {'series': 'Crossfader',
#  'author': 'Restomas',
#  'tracks': [{'title': 'User generated -... breathe and fly',
#    'artist': 'Roland Widmer'},
#   {'title': 'Wasting My Time', 'artist': 'Harry Nilsson'},
#   {'title': 'Working for the Man', 'artist': 'PJ Harvey'},
#   {'title': 'Angeles', 'artist': 'Elliott Smith'},
#   {'title': "Don't Be Cruel", 'artist': 'Billy Swan'},
#   {'title': 'One Night In Prague', 'artist': 'Benny Sings'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'GOLD feat. Cengiz Can', 'artist': 'Nu'},
#   {'title': '50 Ways to Leave Your Lover', 'artist': 'Paul Simon'},
#   {'title': 'Love Song (Helado Negro Remix)', 'artist': 'Devendra Banhart'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Close to You', 'artist': 'Antoine Pesle'},
#   {'title': 'Send a Message', 'artist': 'Amp Fiddler'},
#   {'title': 'Sangria', 'artist': 'Céu'},
#   {'title': 'Tonada de luna llena', 'artist': 'Nella Rojas'},
#   {'title': 'Luscinia megarhy...mmon Nightingale', 'artist': 'Pierre Huguet'},
#   {'title': 'If', 'artist': 'Pink Floyd'},
#   {'title': 'Rancho Grande', 'artist': 'Jean C. Roché'},
#   {'title': 'Vete', 'artist': 'Biig Piig'},
#   {'title': 'Unchained Melody', 'artist': 'The Righteous Brothers'},
#   {'title': 'Werewolf', 'artist': 'Cat Power'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Homemade Ice Cream', 'artist': 'Tony Joe White'},
#   {'title': 'To Li', 'artist': 'Jojo Abot'},
#   {'title': 'I Asked The Mirror', 'artist': 'Tariverdiev (М...л Таривердиев)'},
#   {'title': 'Paloma Negra', 'artist': 'Chavela Vargas'},
#   {'title': 'Risk', 'artist': 'FKJ\xa0(French\xa0Kiwi\xa0Juice)'},
#   {'title': "Didn't I", 'artist': 'Darondo'},
#   {'title': 'Flash Forward', 'artist': 'Serge Gainsbourg'},
#   {'title': 'STATION-ID - Andavoicepur', 'artist': 'Roland Widmer'},
#   {'title': 'I Get a Kick Out...Orchestra Remix)',
#    'artist': 'Ella Fitzgerald'},
#   {'title': 'If You Leave Me Now', 'artist': 'Chicago'},
#   {'title': "I'm Yours", 'artist': 'Mocky'},
#   {'title': 'Carioca', 'artist': 'Fred Astaire'},
#   {'title': 'Smile', 'artist': 'Madeleine Peyroux'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Soft', 'artist': 'Lemon Jelly'},
#   {'title': 'Die Welt ging Un...Grad Im Schatten', 'artist': 'Hildegard Knef'},
#   {'title': 'Mister Echo (Monsieur Écho)', 'artist': 'Patrice et Mario'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Tonada De Luna Llena', 'artist': 'Simón Díaz'},
#   {'title': 'Tangi Tahiti', 'artist': 'Nelson Riddle'},
#   {'title': 'Die Welt ging Un...Grad Im Schatten', 'artist': 'Hildegard Knef'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Gracias a la Vida', 'artist': 'Violeta Parra'},
#   {'title': 'Torch', 'artist': 'M. Ward'},
#   {'title': 'The Day After That', 'artist': 'Matt Elliott'},
#   {'title': 'По Улице Моей Который Год',
#    'artist': 'Tariverdiev (М...л Таривердиев)'},
#   {'title': 'Rancho Grande', 'artist': 'Jean C. Roché'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Mooo!', 'artist': 'Doja Cat'},
#   {'title': 'Sabana de Luz (Live)', 'artist': 'Helado Negro'},
#   {'title': 'Homemade Ice Cream', 'artist': 'Tony Joe White'},
#   {'title': 'Sfiorivano le viole', 'artist': 'Rino Gaetano'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Rock On', 'artist': 'David Essex'},
#   {'title': 'Curly Locks', 'artist': 'Junior Byles'},
#   {'title': 'Can We Teach Each Other', 'artist': 'Cody ChesnuTT'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'I’ve Been Loving You', 'artist': 'The Milk Carton Kids'},
#   {'title': 'Just Me and You', 'artist': 'The Dreamliners'},
#   {'title': 'Feel Alive (Instrumental)', 'artist': 'The Midnight Hour'},
#   {'title': 'Too Many Tears', 'artist': 'Durand Jones & the Indications'},
#   {'title': 'Obiriko Aye N Yilo', 'artist': 'Bola Johnson'},
#   {'title': "Ain't No Sunshine", 'artist': 'The Temptations'},
#   {'title': 'Eighteen With a Bullet', 'artist': 'Derrick Harriott'},
#   {'title': 'Lamento Cubaño', 'artist': 'Guillermo Portabales'},
#   {'title': 'Better Things', 'artist': 'Massive Attack'},
#   {'title': 'By The Time I Get To Phoenix',
#    'artist': 'El\xa0Michels\xa0Affair'},
#   {'title': 'I’m a Fool to Want You', 'artist': 'Donald Byrd'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Elvira O.', 'artist': 'Hildegard Knef'},
#   {'title': 'Jesus', 'artist': 'Curtis Mayfield'},
#   {'title': '06.00 - 09.00 CROSSFADER - lang', 'artist': 'Roland Widmer'},
#   {'title': 'Besame Mucho', 'artist': 'Ray Conniff'},
#   {'title': 'Season of the Witch', 'artist': 'Lana Del Rey'},
#   {'title': 'Chained', 'artist': 'The xx'},
#   {'title': 'Vida antiga', 'artist': 'Erasmo Carlos'},
#   {'title': 'Love Song (Helado Negro Remix)', 'artist': 'Devendra Banhart'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'One Step Ahead', 'artist': 'Aretha Franklin'},
#   {'title': '50 Ways to Leave Your Lover', 'artist': 'Paul Simon'},
#   {'title': "Ma maman m'a dit", 'artist': 'Eugène Mona'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Nont for Sale', 'artist': 'Sudan Archives'},
#   {'title': 'Cien años', 'artist': 'Pedro Infante'},
#   {'title': 'Cucurrucucú Paloma', 'artist': 'Sílvia Pérez Cruz'},
#   {'title': 'Noche Cubana', 'artist': 'Omara Portuondo'},
#   {'title': 'The Loch Ness Monster', 'artist': 'Matilda Mann'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Today Is the First Day', 'artist': 'Penny Goodwin'},
#   {'title': 'Vete', 'artist': 'Biig Piig'},
#   {'title': 'Camadas', 'artist': 'Céu'},
#   {'title': 'Dmtri', 'artist': 'Action Bronson'},
#   {'title': 'Chella llà', 'artist': 'Renato Carosone'},
#   {'title': 'STATION-ID - Closer', 'artist': 'Roland Widmer'},
#   {'title': 'Please Forgive My Heart', 'artist': 'Bobby Womack'},
#   {'title': 'The High', 'artist': 'Kelela'},
#   {'title': 'Comment lui dire', 'artist': 'Camélia Jordana'},
#   {'title': 'Happens to the Heart', 'artist': 'Leonard Cohen'},
#   {'title': 'Angeles', 'artist': 'Elliott Smith'},
#   {'title': 'The End', 'artist': 'Sibylle Baier'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Three Weeks in Havana', 'artist': 'Blake Mills'},
#   {'title': 'The Number Three', 'artist': 'Khruangbin'},
#   {'title': 'Where there is Smoke', 'artist': 'Dominique Fils-Aimé'},
#   {'title': "(I Can't Get Eno...at) Reggae Stuff", 'artist': 'Matumbi'},
#   {'title': 'Sangria', 'artist': 'Easy Life'},
#   {'title': 'STATION-ID - Closer', 'artist': 'Roland Widmer'},
#   {'title': 'Layday', 'artist': 'Young Meyerlack'},
#   {'title': 'Zum-zum', 'artist': 'Edu Lobo'},
#   {'title': 'Blue Bayou', 'artist': 'Linda Ronstadt'},
#   {'title': 'COLLAGE - 10er Reihe 30s', 'artist': 'Roland Widmer'},
#   {'title': 'STATION-ID - Closer', 'artist': 'Roland Widmer'},
#   {'title': 'Sangria', 'artist': 'Céu'},
#   {'title': 'Why Must We Part', 'artist': 'Eddie Harris'},
#   {'title': 'Unchained Melody', 'artist': 'The Righteous Brothers'},
#   {'title': 'STATION-ID - Closer', 'artist': 'Roland Widmer'},
#   {'title': 'Es choge Züüg mit dene Böllä_2', 'artist': 'Roland Widmer'},
#   {'title': 'Love Song', 'artist': 'Devendra Banhart'},
#   {'title': 'Six Feet Under (Jerry Folk Remix)', 'artist': 'Billie Eilish'},
#   {'title': 'Blue Moon', 'artist': 'Julie London'},
#   {'title': 'Odessa Odyssée (Patchwork remix)', 'artist': 'Keren Ann'},
#   {'title': 'Blue Bayou', 'artist': 'Roy Orbison'},
#   {'title': 'Glass Shards', 'artist': 'Laura Misch'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': "I'm Shadowing You", 'artist': 'Blossom Dearie'},
#   {'title': 'Making Chit Chat...t a Dinner Party', 'artist': 'Michael Seyer'},
#   {'title': 'Suzanne', 'artist': 'Françoise Hardy'},
#   {'title': 'Time', 'artist': 'Angelo De Augustine'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'I’m Not in Love', 'artist': 'Kelsey Lu'},
#   {'title': 'Diagonals', 'artist': 'Ladi6'},
#   {'title': 'Es choge Züüg mit dene Böllä_2', 'artist': 'Roland Widmer'},
#   {'title': 'STATION-ID - Doppeler FRO2', 'artist': 'Roland Widmer'},
#   {'title': 'D.M.T.', 'artist': 'Lauren Faith'},
#   {'title': "Hey, That's No Way to Say Goodbye", 'artist': 'Roberta Flack'},
#   {'title': 'Naima', 'artist': 'John Coltrane'},
#   {'title': "Carnaval '74", 'artist': 'DJ Harrison'},
#   {'title': 'Just Like a Baby', 'artist': 'Sly & The Family Stone'},
#   {'title': 'STATION-ID - Closer', 'artist': 'Roland Widmer'},
#   {'title': 'Too Deep', 'artist': 'dvsn'},
#   {'title': 'Magalenha', 'artist': 'Sérgio Mendes'},
#   {'title': 'When Doves Cry', 'artist': 'Ginuwine'},
#   {'title': 'Song For My Father', 'artist': 'Richard "Groove" Holmes'},
#   {'title': 'Soul Lament', 'artist': 'Kenny Burrell'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Sangria', 'artist': 'Céu'},
#   {'title': 'Why Must We Part', 'artist': 'Eddie Harris'},
#   {'title': 'Risk', 'artist': 'FKJ\xa0(French\xa0Kiwi\xa0Juice)'},
#   {'title': 'Unchained Melody', 'artist': 'The Righteous Brothers'},
#   {'title': 'Believer', 'artist': 'Emily King'},
#   {'title': 'Jocelyn Flores', 'artist': 'XXXTENTACION'},
#   {'title': 'Blue Moon', 'artist': 'Julie London'},
#   {'title': '06.00 - 09.00 CROSSFADER - kurz', 'artist': 'Roland Widmer'},
#   {'title': 'Odessa Odyssée (Patchwork remix)', 'artist': 'Keren Ann'},
#   {'title': 'Morning Bell', 'artist': 'Radiohead'},
#   {'title': 'Femme Fatale', 'artist': 'The Velvet Underground'},
#   {'title': 'Six Feet Under (Jerry Folk Remix)', 'artist': 'Billie Eilish'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Killing Me Softly With His Song', 'artist': 'Roberta Flack'},
#   {'title': 'Mona ki ngi xiça', 'artist': 'Bonga'},
#   {'title': 'Blue Bayou', 'artist': 'Roy Orbison'},
#   {'title': 'STATION-ID - Fro electronic', 'artist': 'Roland Widmer'},
#   {'title': 'Woods', 'artist': 'Bon Iver'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Big Bad John', 'artist': 'Jimmy Dean'},
#   {'title': 'I Walk the Line', 'artist': 'Johnny Cash'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Everyone Should Have His Day', 'artist': 'Bobby Wright'},
#   {'title': 'Cog in the Wheel', 'artist': 'Baba Ali'},
#   {'title': 'High Moon', 'artist': 'C.Tappin'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'San Tropez', 'artist': 'Pink Floyd'},
#   {'title': 'Hold On', 'artist': 'Gus Seyffert'},
#   {'title': 'Still Light', 'artist': 'The Knife'},
#   {'title': 'Minimal (DJ Koze Mix)', 'artist': 'Matias Aguayo'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'I Feel Love', 'artist': 'Fingathing'},
#   {'title': 'Ama Sua, Ama Llulla, Ama Kjella', 'artist': 'Luzmila Carpio'},
#   {'title': 'Cumbia de los Ki...vía de Los Kiss)',
#    'artist': 'Los Guacharacos de Colombia'},
#   {'title': 'Quizás, Porque', 'artist': 'Sui Generis'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Spooky [Dub]', 'artist': 'The\xa0Nextmen'},
#   {'title': 'Stay Flo', 'artist': 'Solange'},
#   {'title': 'Gold Teeth', 'artist': 'Blood\xa0Orange'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Sexy Black Timberlake', 'artist': 'Channel Tres'},
#   {'title': "Could've Been", 'artist': 'H.E.R.'},
#   {'title': 'Go Loko', 'artist': 'YG'},
#   {'title': 'Time', 'artist': 'Angelo De Augustine'},
#   {'title': 'Ere Yon', 'artist': 'Julie Coker'},
#   {'title': 'Tonada de luna llena', 'artist': 'Nella Rojas'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Love Song', 'artist': 'Devendra Banhart'},
#   {'title': '06.00 - 09.00 CROSSFADER - lang', 'artist': 'Roland Widmer'},
#   {'title': 'Monotonous Beat', 'artist': 'Mejiwahn'},
#   {'title': 'Chi mai', 'artist': 'Ennio Morricone'},
#   {'title': 'Universe', 'artist': 'Sébastien Tellier'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Degg Gui', 'artist': 'Cheikh\xa0Lô'},
#   {'title': 'Polychromatic', 'artist': 'Castelle'},
#   {'title': 'Cargo culte (version instrumentale)',
#    'artist': 'Serge Gainsbourg'},
#   {'title': 'Track of Tears', 'artist': 'Ken Rob'},
#   {'title': 'Óyelo', 'artist': 'Jimena Angel'},
#   {'title': '06.00 - 09.00 CROSSFADER - lang', 'artist': 'Roland Widmer'},
#   {'title': 'Skypager: Bob Po...Tip) [Interlude]', 'artist': 'J.Period'},
#   {'title': 'Tonada de luna llena', 'artist': 'Nella Rojas'},
#   {'title': 'По Улице Моей Который Год',
#    'artist': 'Tariverdiev (М...л Таривердиев)'},
#   {'title': 'Echo Park', 'artist': 'Bedouine'},
#   {'title': 'Quizás, quizás, quizás', 'artist': 'Trio Los Panchos'},
#   {'title': 'You Can’t Control It', 'artist': 'Jack Johnson'},
#   {'title': 'Cumulous Potion ... Clouds to Sing)',
#    'artist': 'Salami Rose Joe Louis'},
#   {'title': 'Aquarius Outtro [Interlude]', 'artist': 'J.Period'},
#   {'title': 'Hukie Wookie', 'artist': 'Salami Rose Joe Louis'},
#   {'title': 'Emmanuelle', 'artist': 'George Saxon'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Clair', 'artist': 'The Singers Unlimited'},
#   {'title': 'Promise', 'artist': 'Mo Kolours'},
#   {'title': 'A Few More Kisses to Go', 'artist': 'Isaac Hayes'},
#   {'title': 'Degherrem (Remixed by Oscar Lef)', 'artist': 'Julien Jacob'},
#   {'title': 'Killing Me Softly With His Song', 'artist': 'Fugees'},
#   {'title': 'Sinner (Envee Remix)', 'artist': 'Honeyfeet'},
#   {'title': 'Her', 'artist': 'Raury'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': 'Arkadaş', 'artist': 'Melike Demirağ'},
#   {'title': 'Kervan yolda (Schneider TM Remix)', 'artist': 'Baba Zula'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': 'Between the Bars', 'artist': 'Elliott Smith'},
#   {'title': 'Para qué sufrir', 'artist': 'Natalia Lafourcade'},
#   {'title': 'La Javanaise', 'artist': 'Juliette Gréco'},
#   {'title': '06.00 - 09.00 CROSSFADER - kurz', 'artist': 'Roland Widmer'},
#   {'title': 'Orange Moon', 'artist': 'Erykah Badu'},
#   {'title': 'Tonada De Luna Llena', 'artist': 'Simón Díaz'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Blue Alert', 'artist': 'Madeleine Peyroux'},
#   {'title': 'Gayane Ballet Suite (Adagio)',
#    'artist': 'Aram Khatchatu...րամ Խաչատրյան)'},
#   {'title': 'Lying Together', 'artist': 'FKJ (French Kiwi Juice)'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': '06.00 - 09.00 CROSSFADER - kurz', 'artist': 'Roland Widmer'},
#   {'title': 'Cry for Another', 'artist': 'Claude Fontaine'},
#   {'title': 'Harvest Moon', 'artist': 'Jane Birkin'},
#   {'title': 'Imagine', 'artist': 'John Lennon'},
#   {'title': 'STATION ID TEST', 'artist': 'Dr. Lüdi'},
#   {'title': 'Es choge Züüg mit dene Böllä_2', 'artist': 'Roland Widmer'},
#   {'title': 'Melody Noir', 'artist': 'Patrick Watson'},
#   {'title': 'Mafatshi Leh', 'artist': 'Al Massrieen'},
#   {'title': 'All I Wanna Do', 'artist': 'Jakob Ogawa'},
#   {'title': 'All I Need (Edit)', 'artist': 'Air'},
#   {'title': '06.00 - 09.00 CROSSFADER - kurz', 'artist': 'Roland Widmer'},
#   {'title': 'Yali Yali', 'artist': 'Neşe Karaböcek'},
#   {'title': 'Numb', 'artist': 'Men I Trust'},
#   {'title': 'Lord of the Manor', 'artist': 'Everly Brothers'},
#   {'title': 'Weak Spot', 'artist': 'FKA twigs'},
#   {'title': 'بدوية - Badaouiah', 'artist': 'Hany Mehanna'},
#   {'title': '06.00 - 09.00 CROSSFADER - kurz', 'artist': 'Roland Widmer'},
#   {'title': 'And I Love Him', 'artist': 'Esther Phillips'},
#   {'title': 'Goodnight Lovers', 'artist': 'Depeche Mode'},
#   {'title': 'Outré Lux', 'artist': 'Photay'},
#   {'title': 'Sexy Boy (Etienn...r Pistols Remix)', 'artist': 'Air'},
#   {'title': 'Love To Love You Baby', 'artist': 'Rosemary Martins'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'U Ass Bank', 'artist': 'Lyrics Born'},
#   {'title': 'Bossa Nova Trieste', 'artist': 'Shake Keane'},
#   {'title': 'Baby Where You Are', 'artist': 'Ted Lucas'},
#   {'title': 'Always Seems To Get Things Wrong', 'artist': 'Gabi Hartmann'},
#   {'title': 'La Maison près de la fontaine', 'artist': 'Nino Ferrer'},
#   {'title': 'STATION ID TEST', 'artist': 'Dr. Lüdi'},
#   {'title': 'The Operation', 'artist': 'Charlotte Gainsbourg'},
#   {'title': 'Hey Girl (I Like Your Style)', 'artist': 'The Temptations'},
#   {'title': 'Light My Fire', 'artist': 'Astrud Gilberto'},
#   {'title': '06.00 - 09.00 CROSSFADER - kurz', 'artist': 'Roland Widmer'},
#   {'title': 'Xica Xica', 'artist': 'El Buho'},
#   {'title': "Don't Take Your Love Away", 'artist': 'Isaac Hayes'},
#   {'title': 'You Make Me Feel Brand New', 'artist': 'Boris Gardiner'},
#   {'title': 'Baby Where You Are', 'artist': 'Ted Lucas'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Six Feet Under (Jerry Folk Remix)', 'artist': 'Billie Eilish'},
#   {'title': "It's a Circus Out There", 'artist': 'Jason Porter'},
#   {'title': '(There Is) No Greater Love', 'artist': 'Amy Winehouse'},
#   {'title': "Ain't Perfect (Vocal)", 'artist': 'Guts'},
#   {'title': 'Love', 'artist': 'Air'},
#   {'title': 'STATION ID TEST', 'artist': 'Dr. Lüdi'},
#   {'title': 'Rectify', 'artist': 'Moodymann'},
#   {'title': 'Suro Nipa', 'artist': 'K.O.G & the Zongo Brigade'},
#   {'title': 'On & On', 'artist': 'Erykah Badu'},
#   {'title': 'Tadow', 'artist': 'Masego'},
#   {'title': 'Slip', 'artist': 'Elliot Moss'},
#   {'title': 'STATION-ID - Andavoicepur', 'artist': 'Roland Widmer'},
#   {'title': 'Marine Le Pen la...éfenseuse&nbsp;»',
#    'artist': 'Laura\xa0Domenge'},
#   {'title': 'SCHWESTER BERNARDA', 'artist': 'Dr. Lüdi'},
#   {'title': 'Lady DArbanville', 'artist': 'Cat Stevens'},
#   {'title': 'Le Cinema', 'artist': 'Claude Nougaro'},
#   {'title': 'Amphetamine', 'artist': 'Smino'},
#   {'title': 'Deixa a Gira Girar', 'artist': 'Os Tincoãs'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Bullet Proof Soul ft  Sade', 'artist': '2Pac'},
#   {'title': 'The Gap and the Grid', 'artist': 'Acid Pauli'},
#   {'title': 'We Have Love', 'artist': 'Amnesty'},
#   {'title': 'Trois Gnossienne...Gnossienne No. 1', 'artist': 'Erik Satie'},
#   {'title': 'STATION ID TEST', 'artist': 'Dr. Lüdi'},
#   {'title': 'when i was older', 'artist': 'Billie Eilish'},
#   {'title': 'Present Tense: Jonny, Thom & a CR78', 'artist': 'Radiohead'},
#   {'title': 'Boyboy', 'artist': 'Bella Boo'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'U Ass Bank', 'artist': 'Lyrics Born'},
#   {'title': 'Blue Moon', 'artist': 'Elvis Presley'},
#   {'title': 'Mi Negrita', 'artist': 'Devendra Banhart'},
#   {'title': 'Diamonds on a Boat', 'artist': 'Samuel & The Dragon'},
#   {'title': 'One Night In Prague', 'artist': 'Benny Sings'},
#   {'title': 'STATION-ID - Andavoicepur', 'artist': 'Roland Widmer'},
#   {'title': 'Honey', 'artist': 'Raveena'},
#   {'title': 'The Rip', 'artist': 'Portishead'},
#   {'title': 'Something Stupid', 'artist': 'Lola Marsh'},
#   {'title': "I'm Yours", 'artist': 'Mocky'},
#   {'title': "when the party's over", 'artist': 'Billie Eilish'},
#   {'title': 'Hurry', 'artist': 'Teyana\xa0Taylor'},
#   {'title': 'Bury a friend', 'artist': 'Billie Eilish'},
#   {'title': 'Early in the Morning', 'artist': 'Harry Nilsson'},
#   {'title': 'Mad World (Alternate Version)', 'artist': 'Michael Andrews'},
#   {'title': 'Moments in Love', 'artist': 'Art of Noise'},
#   {'title': 'The Look of Love', 'artist': 'Dusty Springfield'},
#   {'title': 'You should see me in a crown', 'artist': 'Billie Eilish'},
#   {'title': 'Warm', 'artist': "Dre'es"},
#   {'title': 'She Wore a Paper Dress', 'artist': 'General Elektriks'},
#   {'title': 'Grilos', 'artist': 'Erasmo Carlos'},
#   {'title': 'COLLAGE - 10er Reihe 45s', 'artist': 'Roland Widmer'},
#   {'title': 'Pause', 'artist': 'Art of Noise'},
#   {'title': 'History Dance', 'artist': 'Blundetto'},
#   {'title': 'Precious Possession', 'artist': 'Anna Wise'},
#   {'title': 'Kiss Me on My Neck (Hesi)', 'artist': 'Erykah Badu'},
#   {'title': 'Lotus Land Op. 47 No. 1', 'artist': 'Fritz Kreisler'},
#   {'title': 'Nèg Dafrik', 'artist': 'Boulpik'},
#   {'title': "Let's Dance", 'artist': 'M. Ward'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Camarada (Jongo Guerrilheiro)',
#    'artist': 'Moussu T e lei jovents'},
#   {'title': 'Era di maggio', 'artist': 'Roberto Murolo'},
#   {'title': 'STATION ID TEST', 'artist': 'Dr. Lüdi'},
#   {'title': 'The Crave', 'artist': 'Baron Rétif & Concepción Perez'},
#   {'title': '06.00 - 09.00 CROSSFADER - kurz', 'artist': 'Roland Widmer'},
#   {'title': 'STATION-ID - Cutter kurz', 'artist': 'Roland Widmer'},
#   {'title': 'Got It Going On (Aim remix)', 'artist': 'Deadbeats'},
#   {'title': 'Illuminate', 'artist': 'Lateef\xa0the\xa0Truth\xa0Speaker'},
#   {'title': 'Lying Together', 'artist': 'FKJ (French Kiwi Juice)'},
#   {'title': 'So Sexy', 'artist': 'Lateef the Truth Speaker'},
#   {'title': 'La Gitana Me Ha ...lsa Electrónica)',
#    'artist': 'Meridian Brothers'},
#   {'title': "Lemon (Nova's Edit)", 'artist': 'Bachar Khalifé'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Cotonou', 'artist': 'Julien Jacob'},
#   {'title': 'Mile High Swinger', 'artist': 'Alan\xa0Hawkshaw'},
#   {'title': 'Prediction', 'artist': 'Steel Pulse'},
#   {'title': 'Impulsion', 'artist': 'Barry\xa0Morgan'},
#   {'title': 'Eu e você', 'artist': 'Stan Getz'},
#   {'title': 'Bloodshot Eyes', 'artist': 'General Elektriks'},
#   {'title': 'Liquid Sunshine', 'artist': 'John Cameron'},
#   {'title': 'Sahara Sunrise', 'artist': 'John Cameron'},
#   {'title': '06.00 - 09.00 CROSSFADER - kurz', 'artist': 'Roland Widmer'},
#   {'title': 'Gogol', 'artist': 'Gonzales'},
#   {'title': 'Space Talk', 'artist': 'Asha Puthli'},
#   {'title': 'Drifter in the Dark', 'artist': 'Ween'},
#   {'title': 'My Baby Just Cares for Me', 'artist': 'Nina Simone'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'One Evening', 'artist': 'Feist'},
#   {'title': 'Headphone Drone (7 Inch Edit)', 'artist': 'Blackjoy'},
#   {'title': 'Excuse Me', 'artist': 'Pigeon John'},
#   {'title': 'And So It Goes (RSS Disco Edit)', 'artist': 'Graham Nash'},
#   {'title': 'Passagers', 'artist': 'Canari'},
#   {'title': 'Clouds Across The Moon', 'artist': 'RAH Band'},
#   {'title': 'Megajoy / J-Pop', 'artist': 'kidkanevil'},
#   {'title': 'Take You Out Tonight',
#    'artist': 'Lateef\xa0the\xa0Truth\xa0Speaker'},
#   {'title': 'STATION-ID - Cutter kurz', 'artist': 'Roland Widmer'},
#   {'title': '06.00 - 09.00 CROSSFADER - kurz', 'artist': 'Roland Widmer'},
#   {'title': 'STATION-ID - Cutter kurz', 'artist': 'Roland Widmer'},
#   {'title': 'Pressure & Slide', 'artist': 'The Tennors'},
#   {'title': 'Tia', 'artist': 'Artur Nunes'},
#   {'title': 'Intro', 'artist': 'Don Leisure'},
#   {'title': 'Nèg Dafrik', 'artist': 'Boulpik'},
#   {'title': 'Smile', 'artist': 'Madeleine Peyroux'},
#   {'title': 'City Lights (Pt.2)', 'artist': 'Greyboy'},
#   {'title': 'Shuggie Pie', 'artist': 'Mocky'},
#   {'title': 'Running Deers', 'artist': 'Clutchy Hopkins'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Slogan Aftershafe Normalo', 'artist': 'Andres Lutz'},
#   {'title': 'Bangu', 'artist': 'Radio Citizen'},
#   {'title': 'Busy Line', 'artist': 'Rose Murphy'},
#   {'title': 'To Li', 'artist': 'Jojo Abot'},
#   {'title': 'Silbo', 'artist': 'Féloche'},
#   {'title': "I'm Yours", 'artist': 'Mocky'},
#   {'title': 'Interlude', 'artist': 'Thievery Corporation'},
#   {'title': 'A Lazy Day (with Organ)', 'artist': 'Allen Toussaint'},
#   {'title': 'Precious Possession', 'artist': 'Anna Wise'},
#   {'title': 'La Juanda', 'artist': 'Chuck Berry'},
#   {'title': 'Academy Award', 'artist': 'Andres Lutz'},
#   {'title': 'Riemestalde Chilbi und Zenali', 'artist': 'Rees Gwerder'},
#   {'title': 'Red Wine', 'artist': 'Bibi Tanga & The Selenites'},
#   {'title': 'Mulher Rendeira', 'artist': 'Osmar Milito'},
#   {'title': 'How Will I Know You', 'artist': 'Mocky'},
#   {'title': 'The Crave', 'artist': 'Baron Rétif & Concepción Perez'},
#   {'title': 'Kokopelli', 'artist': 'Mild High Club'},
#   {'title': "We're All Alone", 'artist': 'Doreen Shaffer'},
#   {'title': 'Banzaï', 'artist': 'Expérience 7'},
#   {'title': 'Hotel California', 'artist': '7-A-Side'},
#   {'title': '06.00 - 09.00 CROSSFADER - kurz', 'artist': 'Roland Widmer'},
#   {'title': '06.00 - 09.00 CROSSFADER - kurz', 'artist': 'Roland Widmer'},
#   {'title': 'Seabird', 'artist': 'Alessi Brothers'},
#   {'title': 'John Jones', 'artist': 'Van Dyke Parks'},
#   {'title': 'Belina', 'artist': 'Artur Nunes'},
#   {'title': 'Oh-lala', 'artist': 'Saint Privat'},
#   {'title': 'Rocky Raccoon', 'artist': 'The Beatles'},
#   {'title': 'New kid in town', 'artist': '7-A-Side'},
#   {'title': 'The Girl From Ipanema', 'artist': 'Stan Getz'},
#   {'title': 'Tears (Patchworks remix)', 'artist': 'John Milk'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': 'Valley in the Ocean', 'artist': 'Bruno Pernadas'},
#   {'title': 'Pesse Mi Buntare', 'artist': 'Yta Jourias'},
#   {'title': 'Johnny Head-in-Air', 'artist': 'The Tiger Lillies'},
#   {'title': 'Maria', 'artist': 'Joao Selva'},
#   {'title': 'STATION-ID - Doppeler', 'artist': 'Roland Widmer'},
#   {'title': "I Should've Spoke Up", 'artist': 'The James Hunter Six'},
#   {'title': 'Memoria del árbol', 'artist': 'Los Cafres'},
#   {'title': 'The Story Of The Mongolian Horse', 'artist': 'Marsmobil'},
#   {'title': 'Habesha', 'artist': "Te'amir"},
#   {'title': 'La Noche (vocal)', 'artist': 'Juan García Esquivel'},
#   {'title': '06.00 - 09.00 CROSSFADER - kurz', 'artist': 'Roland Widmer'},
#   {'title': 'One Night In Prague', 'artist': 'Benny Sings'},
#   {'title': "Everybody's Talkin'", 'artist': 'Claude Denjean'},
#   {'title': 'Walk with the Dreamers', 'artist': 'Ambala'},
#   {'title': 'Tia', 'artist': 'Artur Nunes'},
#   {'title': 'Dreams Of Love', 'artist': 'Claude Genteuil'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': 'Flute Song', 'artist': 'Wildflower'},
#   {'title': 'Poinciana', 'artist': 'Frank Hunter and His Orchestra'},
#   {'title': 'Susanna', 'artist': 'Adriano Celentano'},
#   {'title': 'Bakerman (Extended Remix)', 'artist': 'Laidback'},
#   {'title': 'The Creator', 'artist': 'Aisha'},
#   {'title': "Why Can't We Live Together", 'artist': 'Illusion'},
#   {'title': 'Summer Samba (So Nice)', 'artist': 'Walter Wanderley'},
#   {'title': 'Mile End', 'artist': 'Pulp'},
#   {'title': "Si Tu T'imagines", 'artist': 'Juliette Gréco'},
#   {'title': 'STATION-ID - Fro electronic', 'artist': 'Roland Widmer'},
#   {'title': '06.00 - 09.00 CROSSFADER - kurz', 'artist': 'Roland Widmer'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Orientaçao', 'artist': 'Tuze De Abreu'},
#   {'title': 'Sunny Goodge Street', 'artist': 'Donovan'},
#   {'title': 'Help Yourself', 'artist': 'Amy Winehouse'},
#   {'title': 'Höräd Uf', 'artist': 'Nanalee Vãonger'},
#   {'title': 'Uh Uh...', 'artist': 'EKR'},
#   {'title': 'Deadweight', 'artist': 'Beck'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': 'Sämeli', 'artist': 'Véronique Müller'},
#   {'title': 'Stuck (original)', 'artist': 'Peven Everett'},
#   {'title': 'Our Day Will Come', 'artist': 'Amy Winehouse'},
#   {'title': 'Grilos', 'artist': 'Erasmo Carlos'},
#   {'title': 'Sentado à beira do caminho', 'artist': 'Erasmo Carlos'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Interlude', 'artist': 'J Dilla'},
#   {'title': 'The Star of a Story', 'artist': 'Heatwave'},
#   {'title': 'Blue Moon', 'artist': 'Elvis Presley'},
#   {'title': 'Cung Đàn Đât Nuóc', 'artist': 'Thanh Tâm'},
#   {'title': 'Belina', 'artist': 'Artur Nunes'},
#   {'title': 'Oh Love', 'artist': 'Jonwayne'},
#   {'title': 'Nissim', 'artist': 'The\xa0Gaslamp\xa0Killer'},
#   {'title': 'Natural High', 'artist': 'Bloodstone'},
#   {'title': 'Invitation', 'artist': 'The Guitars, Inc.'},
#   {'title': 'Alturas', 'artist': 'Inti-Illimani'},
#   {'title': 'Disco Love', 'artist': 'Gene Evaro Jr.'},
#   {'title': 'STATION-ID - Knockcast', 'artist': 'Roland Widmer'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': '06.00 - 09.00 CROSSFADER - kurz', 'artist': 'Roland Widmer'},
#   {'title': 'Nightvision', 'artist': 'Daft Punk'},
#   {'title': 'Song of the jumbies', 'artist': 'Josephine Premice'},
#   {'title': 'Pal Perú', 'artist': 'Gecko Turner'},
#   {'title': 'Suit & Tie (John... Reggae Version)', 'artist': 'John Milk'},
#   {'title': 'Sweet and Loving Man', 'artist': 'Finley Quaye'},
#   {'title': 'Kiss Me on My Neck (Hesi)', 'artist': 'Erykah Badu'},
#   {'title': 'Summer Madness', 'artist': 'Kool & The Gang'},
#   {'title': 'Orientaçao', 'artist': 'Tuze De Abreu'},
#   {'title': 'Scalinatella', 'artist': 'Roberto Murolo'},
#   {'title': 'Bèmen sèbèb letlash', 'artist': 'Mahmoud Ahmed'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': 'You Took Your Ti...eat. King Krule)',
#    'artist': 'Mount\xa0Kimbie'},
#   {'title': 'Unicorn In Uniform', 'artist': 'Connan Mockasin'},
#   {'title': 'Karmacoma (Portishead Experience)', 'artist': 'Massive Attack'},
#   {'title': 'Duke', 'artist': 'Romano Mussolini'},
#   {'title': "I'm Just Here (Wyndham Earl remix)", 'artist': 'Alice Russell'},
#   {'title': 'Irene', 'artist': 'Caribou'},
#   {'title': 'Papa Was A Rolling Stone', 'artist': 'The Temptations'},
#   {'title': 'El Boog', 'artist': 'Eugene Harrington'},
#   {'title': 'Big Rock Candy M... Out Sweet Land)', 'artist': 'Burl Ives'},
#   {'title': 'STATION-ID - Fro electronic', 'artist': 'Roland Widmer'},
#   {'title': 'Walzer für S.', 'artist': 'Saalschutz'},
#   {'title': 'À bicyclette', 'artist': 'Yves Montand'},
#   {'title': 'Greece: Instrumental', 'artist': '(unknown)'},
#   {'title': 'Cool Water', 'artist': 'Sons of the Pioneers'},
#   {'title': 'Banderilla', 'artist': 'Calexico'},
#   {'title': 'Woo', 'artist': 'Erykah Badu'},
#   {'title': 'Woman (Eprom Remix)', 'artist': 'Rhye'},
#   {'title': 'Everybody Loves the Sunshine', 'artist': 'Ramp'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': 'STATION-ID - Knockcast', 'artist': 'Roland Widmer'},
#   {'title': 'Bulan Dagoan', 'artist': 'Yanti Bersaudara'},
#   {'title': 'We Need Love', 'artist': 'Johnny Osbourne'},
#   {'title': 'Marie Laforet I (Tu Fais Semblant)', 'artist': 'Mounika'},
#   {'title': 'Something About Us', 'artist': 'Daft Punk'},
#   {'title': 'Mi Negrita', 'artist': 'Devendra Banhart'},
#   {'title': 'Planet Caravan', 'artist': 'Black Sabbath'},
#   {'title': 'Perfidia', 'artist': 'Nat King Cole'},
#   {'title': 'Veridis Quo', 'artist': 'Daft Punk'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Autumn in New York (LP take)', 'artist': 'Billie Holiday'},
#   {'title': 'Flume', 'artist': 'Bon Iver'},
#   {'title': 'Mister Cool T', 'artist': 'Afrobeat Makers'},
#   {'title': 'Solar (Six Too remix)', 'artist': 'Domenico + 2'},
#   {'title': 'Senza un perché', 'artist': 'Nada'},
#   {'title': 'Ma solitude', 'artist': 'Marc Lavoine'},
#   {'title': 'Ghost Ship in a Storm', 'artist': 'Jim O’Rourke'},
#   {'title': 'Coconut Grove', 'artist': 'The Lovin’ Spoonful'},
#   {'title': 'Fly Me to the Moon', 'artist': 'Astrud Gilberto'},
#   {'title': 'Time Is Tight', 'artist': 'Booker T. & The MG’s'},
#   {'title': '1:14', 'artist': 'Misled Children'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': 'A Good Deal', 'artist': 'Eels'},
#   {'title': 'Grilos', 'artist': 'Erasmo Carlos'},
#   {'title': 'Animaletti', 'artist': 'Ennio Morricone'},
#   {'title': 'Ladies Love Chest Rockwell',
#    'artist': 'Nathaniel\xa0Merriweather'},
#   {'title': 'Fly Robin Fly', 'artist': 'Silver Convention'},
#   {'title': 'Lovage (Love That Lovage, Baby)',
#    'artist': 'Nathaniel\xa0Merriweather'},
#   {'title': 'Doin’ It Right', 'artist': 'Daft Punk'},
#   {'title': 'Terms And Conditions Apply', 'artist': 'General Elektriks'},
#   {'title': 'Mara', 'artist': 'Devendra Banhart'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Oasis of Dakhla', 'artist': 'Les Baxter'},
#   {'title': 'Happy Together', 'artist': 'James Combs'},
#   {'title': 'Money Nor Bataya', 'artist': 'Afro National'},
#   {'title': 'Pharoah', 'artist': 'Topaz'},
#   {'title': 'El Toro (Mark De Clive Low Remix)', 'artist': 'Chico Hamilton'},
#   {'title': 'Preciso Dizer Que Te Amo', 'artist': 'Cazuza'},
#   {'title': 'Tsetse Fly', 'artist': 'Martin Denny'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': '06.00 - 09.00 CROSSFADER - lang', 'artist': 'Roland Widmer'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': 'Parachute', 'artist': 'General Elektriks'},
#   {'title': "Don't Be Cruel", 'artist': 'Billy Swan'},
#   {'title': "You're Drifting", 'artist': 'General Elektriks'},
#   {'title': 'Lucy In The Sky With Diamonds', 'artist': 'Gábor Szabó'},
#   {'title': 'Paperbag Writer', 'artist': 'Radiohead'},
#   {'title': 'She’s a Lady', 'artist': 'Tom Jones'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': 'Scarborough Fair / Canticle', 'artist': 'Simon & Garfunkel'},
#   {'title': "There's A War", 'artist': 'Taha Aitabi'},
#   {'title': 'Mysteries', 'artist': 'Beth\xa0Gibbons'},
#   {'title': 'Black', 'artist': 'Cat Power'},
#   {'title': 'El cóndor pasa (If I Could)', 'artist': 'Simon & Garfunkel'},
#   {'title': '06.00 - 09.00 CROSSFADER - lang', 'artist': 'Roland Widmer'},
#   {'title': 'Latino Chrome', 'artist': 'Jim Morrison'},
#   {'title': 'Willkomme in Züri', 'artist': 'Skor'},
#   {'title': 'The Heat', 'artist': 'Jungle'},
#   {'title': 'Possibilities', 'artist': 'Amp Fiddler'},
#   {'title': 'Outro', 'artist': 'DJ Fab'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': '06.00 - 09.00 CROSSFADER - lang', 'artist': 'Roland Widmer'},
#   {'title': 'Island Letter', 'artist': 'Shuggie Otis'},
#   {'title': 'Dirty Trip', 'artist': 'Air'},
#   {'title': 'Lovely Head', 'artist': 'Goldfrapp'},
#   {'title': 'Veridis Quo', 'artist': 'Daft Punk'},
#   {'title': 'I Will (Los Angeles version)', 'artist': 'Radiohead'},
#   {'title': 'Passing By', 'artist': 'Zero 7'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Melody', 'artist': 'Serge Gainsbourg'},
#   {'title': 'Tower of Song', 'artist': 'Leonard Cohen'},
#   {'title': 'Lapse', 'artist': 'Bill Callahan'},
#   {'title': 'Mais um Lamento', 'artist': 'Céu'},
#   {'title': 'Creep (acoustic)', 'artist': 'Radiohead'},
#   {'title': 'Are You Lonesome To-Night?', 'artist': 'Elvis Presley'},
#   {'title': 'Müzik Moğolları', 'artist': 'Moğollar'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Dreaming of an Anthill (Teeming)', 'artist': 'The Residents'},
#   {'title': 'Dreams', 'artist': 'Fleetwood Mac'},
#   {'title': 'Stuck With Me', 'artist': 'Timeflies'},
#   {'title': 'Bury Me by the River', 'artist': 'Kutmah'},
#   {'title': 'Chant of the Moon', 'artist': 'Robert Drasnin'},
#   {'title': 'Undenied', 'artist': 'Portishead'},
#   {'title': 'I Wish I Was a M...round (extended)', 'artist': 'ANBB'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': 'Early in the Morning', 'artist': 'Harry Nilsson'},
#   {'title': 'Love of a Woman (feat. Darondo)', 'artist': 'Clutchy Hopkins'},
#   {'title': 'Ich Liebe Euch (DJ Koze Remix)', 'artist': 'Hildegard Knef'},
#   {'title': 'You Make It Easy', 'artist': 'Air'},
#   {'title': 'Come Softly to Me', 'artist': 'The Fleetwoods'},
#   {'title': 'Duet', 'artist': 'GonjaSufi'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Diamond Day', 'artist': 'Vashti Bunyan'},
#   {'title': 'Come Wander With Me', 'artist': 'Jeff Alexander'},
#   {'title': 'The Rip', 'artist': 'Portishead'},
#   {'title': 'Because', 'artist': 'Elliott Smith'},
#   {'title': 'The Vagabond', 'artist': 'Air'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Blind Lemon Man (Dub)', 'artist': 'Baba Zula'},
#   {'title': 'The Teardrop Collector', 'artist': 'Love and Rockets'},
#   {'title': 'Space Oddity', 'artist': 'David Bowie'},
#   {'title': 'National Movie Review', 'artist': 'Deltron 3030'},
#   {'title': "It's a Circus Out There", 'artist': 'Jason Porter'},
#   {'title': 'Sweet Apocalypse', 'artist': 'Moby'},
#   {'title': "Eli's Game", 'artist': 'Al Green'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': '06.00 - 09.00 CROSSFADER - lang', 'artist': 'Roland Widmer'},
#   {'title': 'One', 'artist': 'Harry Nilsson'},
#   {'title': 'Seahorse', 'artist': 'Devendra Banhart'},
#   {'title': 'Something Stupid', 'artist': 'Lola Marsh'},
#   {'title': 'Fu Man Chu', 'artist': 'Desmond Dekker'},
#   {'title': 'Carioca', 'artist': 'Fred Astaire'},
#   {'title': 'Torna pulicinella', 'artist': 'Roberto Murolo'},
#   {'title': "Everybody's Talkin'", 'artist': 'Harry Nilsson'},
#   {'title': "Benny's Grave", 'artist': 'Swan Dive'},
#   {'title': 'It Mek', 'artist': 'Desmond Dekker'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'The Sound of Silence', 'artist': 'Simon & Garfunkel'},
#   {'title': 'Remember (D. Whitaker version)', 'artist': 'Air'},
#   {'title': 'Turn Around (Âme Remix)', 'artist': 'Sailor & I'},
#   {'title': 'Exit Music (for a Film)', 'artist': 'Radiohead'},
#   {'title': 'Our Prayer / Gee', 'artist': 'Brian Wilson'},
#   {'title': 'El Condor Pasa', 'artist': 'The Wainwright Sisters'},
#   {'title': 'Problems With the Sun', 'artist': 'Nicolas Jaar'},
#   {'title': 'Closer to You', 'artist': 'Daniel Ash'},
#   {'title': 'Soft', 'artist': 'Lemon Jelly'},
#   {'title': 'Arkadaşlar İyidir', 'artist': 'Baba Zula'},
#   {'title': 'I Get a Kick Out...Orchestra Remix)',
#    'artist': 'Ella Fitzgerald'},
#   {'title': 'Werewolf', 'artist': 'Cat Power'},
#   {'title': 'Packt Like Sardi...a Crushd Tin Box', 'artist': 'Radiohead'},
#   {'title': 'Bulan Dagoan', 'artist': 'Yanti Bersaudara'},
#   {'title': '06.00 - 09.00 CROSSFADER - lang', 'artist': 'Roland Widmer'},
#   {'title': 'The Windmills Of Your Mind', 'artist': 'Dusty Springfield'},
#   {'title': 'Beautiful Kahana', 'artist': 'Arthur Lyman'},
#   {'title': "It's a Beautiful Day", 'artist': 'Liverpool Express'},
#   {'title': 'Migration Feathers', 'artist': 'General Elektriks'},
#   {'title': 'Stranger in Paradise', 'artist': 'Arthur Lyman'},
#   {'title': 'Caravan (Cool Version)', 'artist': 'Duke Ellington'},
#   {'title': 'Siempre me quedará', 'artist': 'Bebe'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': 'Elvis on the Rad...uitar in My Soul', 'artist': 'The KLF'},
#   {'title': 'Sweet Leilani', 'artist': 'The Arthur Lyman Group'},
#   {'title': 'The Vagabond', 'artist': 'Air'},
#   {'title': 'Doin’ It Right', 'artist': 'Daft Punk'},
#   {'title': 'Coconut Grove', 'artist': 'The Lovin’ Spoonful'},
#   {'title': 'Baubles, Bangles and Beads', 'artist': 'Frank\xa0Sinatra'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': 'Brindo', 'artist': 'Devendra Banhart'},
#   {'title': 'Cups', 'artist': 'Underworld'},
#   {'title': 'Mellow Mood (Jahno dub)', 'artist': 'Soul Sugar'},
#   {'title': "You're My Thrill", 'artist': 'Peggy Lee'},
#   {'title': 'The Hours', 'artist': 'kidkanevil'},
#   {'title': 'How Deep Is Your Love', 'artist': 'Bee Gees'},
#   {'title': '3:25', 'artist': 'Clutchy Hopkins'},
#   {'title': 'If You Leave Me Now', 'artist': 'Chicago'},
#   {'title': 'On the Run', 'artist': 'Moodymann'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': '06.00 - 09.00 CROSSFADER - lang', 'artist': 'Roland Widmer'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': 'Anna Lee, the Healer', 'artist': 'The High Llamas'},
#   {'title': 'Behind', 'artist': 'Harco Pront'},
#   {'title': 'Hello!', 'artist': 'International Pony'},
#   {'title': 'El Diablo En El Ojo', 'artist': 'Tindersticks'},
#   {'title': 'Two Wooden Spoons', 'artist': 'This Is the Kit'},
#   {'title': 'Honey Sun', 'artist': 'Elbow'},
#   {'title': 'Ready Or Not', 'artist': 'Gil Scott-Heron'},
#   {'title': 'Song Of The Wind', 'artist': 'Kentyah'},
#   {'title': "Help Me Out Y'all", 'artist': 'kidkanevil'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Spur 14', 'artist': 'Andres Lutz'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'i miss you so', 'artist': 'Salami Rose Joe Louis'},
#   {'title': 'Dayvan Cowboy', 'artist': 'Boards of Canada'},
#   {'title': 'Showing Shadows', 'artist': 'R. Stevie Moore'},
#   {'title': 'Sugar Cane', 'artist': 'Don Paulin'},
#   {'title': 'Mestiça', 'artist': 'Zé Ramalho'},
#   {'title': 'Cangote', 'artist': 'Céu'},
#   {'title': 'User generated - english - ruhig', 'artist': 'Roland Widmer'},
#   {'title': 'Something Stupid', 'artist': 'Lola Marsh'},
#   {'title': "If You Didn't Lo... (Don't Go Away)", 'artist': 'D.J. Rogers'},
#   {'title': "Eli's Game", 'artist': 'Al Green'},
#   {'title': 'We Need Love', 'artist': 'Johnny Osbourne'},
#   {'title': 'How Deep Is Your Love', 'artist': 'Bee Gees'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': '06.00 - 09.00 CROSSFADER - lang', 'artist': 'Roland Widmer'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Heart Of The Country', 'artist': 'Paul\xa0McCartney'},
#   {'title': 'Ce n’est que de l’eau', 'artist': 'Pierre Barouh'},
#   {'title': 'Sleep Walk', 'artist': 'Pete Drake'},
#   {'title': 'Moritat (A Theme...ee Penny Opera”)',
#    'artist': 'The Dick Hyman Trio'},
#   {'title': 'Besame Mucho', 'artist': 'Luis Fernando Zepeda'},
#   {'title': 'Gotta Do My Best', 'artist': 'Chris Harwood'},
#   {'title': 'Albatross', 'artist': 'Fleetwood Mac'},
#   {'title': 'STATION-ID - Doppeler', 'artist': 'Roland Widmer'},
#   {'title': 'Birds Of A Feather (Radio Edit)', 'artist': 'Mocky'},
#   {'title': "A Hard Day's Night", 'artist': 'Tee and Cara'},
#   {'title': "Didn't We (Skit)", 'artist': 'DJ Scientist'},
#   {'title': 'GertSoul Guitar', 'artist': 'Gert Wilden & Orchestra'},
#   {'title': 'Make Love to Me', 'artist': 'Carrie Cleveland'},
#   {'title': 'The Man Who Sold the World', 'artist': 'David Bowie'},
#   {'title': "Lovin' You", 'artist': 'Minnie Riperton'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': "Everybody's Talkin'", 'artist': 'Harry Nilsson'},
#   {'title': 'Drinking Water (...io Carlos Jobim]',
#    'artist': 'Frank\xa0Sinatra'},
#   {'title': 'The Look of Love', 'artist': 'Dusty Springfield'},
#   {'title': 'Anyone Who Had A Heart', 'artist': 'Dusty Springfield'},
#   {'title': 'Undertow', 'artist': 'Warpaint'},
#   {'title': 'The Overachievers', 'artist': 'Liars'},
#   {'title': 'Time In a Bottle', 'artist': 'Jim Croce'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': '06.00 - 09.00 CROSSFADER - lang', 'artist': 'Roland Widmer'},
#   {'title': 'Space Oddity', 'artist': 'David Bowie'},
#   {'title': 'White Bird', 'artist': 'It’s a Beautiful Day'},
#   {'title': "Victoria's Secret", 'artist': 'Quiet Village'},
#   {'title': 'The Man I Love', 'artist': 'Caetano Veloso'},
#   {'title': 'Fvckin Vbortion', 'artist': 'SoberOne'},
#   {'title': "My Autumn's Done Come", 'artist': 'Lee Hazlewood'},
#   {'title': 'Only You', 'artist': 'Portishead'},
#   {'title': 'User generated - english - ruhig', 'artist': 'Roland Widmer'},
#   {'title': 'Scenes From...', 'artist': 'Money Mark'},
#   {'title': 'She Wore a Paper Dress', 'artist': 'General Elektriks'},
#   {'title': 'Someone Like You', 'artist': 'Paolo Nutini'},
#   {'title': 'Song Of The Wind', 'artist': 'Kentyah'},
#   {'title': 'Sexy Mother Fakir', 'artist': 'Kalyanji Anandji'},
#   {'title': 'Parole parole', 'artist': 'Mina'},
#   {'title': 'I Get Low', 'artist': 'Timber Timbre'},
#   {'title': 'Come With Me', 'artist': 'Jonny Trunk'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': '06.00 - 09.00 CROSSFADER - lang', 'artist': 'Roland Widmer'},
#   {'title': 'Oh Solo', 'artist': 'The Cairo Gang'},
#   {'title': 'Pause', 'artist': 'Art of Noise'},
#   {'title': 'G.I. Right', 'artist': 'Kinny & Horne'},
#   {'title': 'Mi Negrita', 'artist': 'Devendra Banhart'},
#   {'title': 'One More', 'artist': 'Cymande'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Interview / Comanche', 'artist': 'Quentin\xa0Tarantino'},
#   {'title': 'Dreams', 'artist': 'Fleetwood Mac'},
#   {'title': 'Sunny', 'artist': 'Bobby Hebb'},
#   {'title': 'Ladies Love Chest Rockwell',
#    'artist': 'Nathaniel\xa0Merriweather'},
#   {'title': 'Two Hearts Combine', 'artist': 'Venice Dawn'},
#   {'title': 'Sleep Walk', 'artist': 'Santo & Johnny'},
#   {'title': "I'm Confessin' (That I Love You)",
#    'artist': 'Les Paul & Mary Ford'},
#   {'title': 'User generated - english - ruhig', 'artist': 'Roland Widmer'},
#   {'title': "Cheers Darlin'", 'artist': 'Damien Rice'},
#   {'title': 'Should Have Known Better', 'artist': 'Sufjan Stevens'},
#   {'title': '8 Ball', 'artist': 'Underworld'},
#   {'title': 'One Love for Boognish', 'artist': 'Ween'},
#   {'title': 'Going Up the Country', 'artist': 'Canned Heat'},
#   {'title': 'STATION-ID - Doppeler', 'artist': 'Roland Widmer'},
#   {'title': 'La Vie En Rose', 'artist': 'Louis Armstrong'},
#   {'title': 'Fly Me to the Moon', 'artist': 'Astrud Gilberto'},
#   {'title': "Carlotta's Portrait", 'artist': 'Bernard Herrmann'},
#   {'title': 'Roomboy', 'artist': 'Flatpocket'},
#   {'title': "A Hard Day's Night", 'artist': 'Tee and Cara'},
#   {'title': 'STATION-ID - Fro electronic', 'artist': 'Roland Widmer'},
#   {'title': 'Mica Tanto', 'artist': 'Monica\xa0Vitti'},
#   {'title': 'Vacation Island', 'artist': 'Kid Koala'},
#   {'title': 'Manifold de Amour', 'artist': 'Latin Playboys'},
#   {'title': 'Disco Love', 'artist': 'Gene Evaro Jr.'},
#   {'title': 'Take 2 Blue', 'artist': 'Bitter:Sweet'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Famous Blue Raincoat', 'artist': 'Marissa Nadler'},
#   {'title': 'Gasoline Horseys (Live)', 'artist': 'Sparklehorse'},
#   {'title': 'Blow My Mind (In...onal Pony remix)',
#    'artist': 'DeeJay\xa0Punk-Roc'},
#   {'title': 'Baby', 'artist': 'Ariel Pink’s Haunted Graffiti'},
#   {'title': 'Series of Misunderstandings', 'artist': 'Eels'},
#   {'title': "Help Me Out Y'all", 'artist': 'kidkanevil'},
#   {'title': 'Adieu', 'artist': 'Fischmob'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'COLLAGE - 10er Reihe 30s', 'artist': 'Roland Widmer'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': 'President Chimp Toe', 'artist': 'Fila Brazillia'},
#   {'title': 'That Strange Rhythm', 'artist': 'Vista\xa0Le\xa0Vie'},
#   {'title': 'Crime In Stereo', 'artist': 'Vista\xa0Le\xa0Vie'},
#   {'title': "Won't Let You leave", 'artist': 'Jenny O.'},
#   {'title': 'Brindo', 'artist': 'Devendra Banhart'},
#   {'title': 'The Sound of Silence', 'artist': 'Simon & Garfunkel'},
#   {'title': 'Flamingo', 'artist': 'The Gene Rains Group'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Walking In The Dark', 'artist': 'Stefano Torossi'},
#   {'title': 'Sweet Leilani', 'artist': 'Chris Isaak'},
#   {'title': 'Dream', 'artist': 'The Pied Pipers'},
#   {'title': "97 BPM ***IT'S OVER", 'artist': 'Kutmah'},
#   {'title': "Wouldn't Waste", 'artist': 'Woods'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': 'Sleeping Bag', 'artist': 'Beck'},
#   {'title': 'Sentado à beira do caminho', 'artist': 'Erasmo Carlos'},
#   {'title': 'Albatross', 'artist': 'Fleetwood Mac'},
#   {'title': 'Flume', 'artist': 'Bon Iver'},
#   {'title': 'Well OK Honey', 'artist': 'Jenny O.'},
#   {'title': 'Grilos', 'artist': 'Erasmo Carlos'},
#   {'title': 'STATION-ID - Closer', 'artist': 'Roland Widmer'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': '06.00 - 09.00 CROSSFADER - lang', 'artist': 'Roland Widmer'},
#   {'title': 'Era di maggio', 'artist': 'Roberto Murolo'},
#   {'title': 'El Condor Pasa', 'artist': 'The Wainwright Sisters'},
#   {'title': 'DinDi', 'artist': 'Willie Bobo & The Bo Gents'},
#   {'title': 'Sweet Leilani', 'artist': 'Chris Isaak'},
#   {'title': 'Laura', 'artist': 'Collage'},
#   {'title': 'Historia de amor (Love Story)', 'artist': 'Astrud\xa0Gilberto'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': 'Superstar', 'artist': 'The Performers'},
#   {'title': 'Suzanne', 'artist': 'Leonard Cohen'},
#   {'title': 'Remember (D. Whitaker version)', 'artist': 'Air'},
#   {'title': 'Never, Never Gonna Give You Up', 'artist': 'Barry White'},
#   {'title': 'Summer in the City', 'artist': 'Quincy Jones'},
#   {'title': "L'amore dice ciao", 'artist': 'Armando Trovajoli'},
#   {'title': 'River Man', 'artist': 'Nick Drake'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'The Boy From Ipanema', 'artist': 'Nancy Wilson'},
#   {'title': 'The Hours', 'artist': 'kidkanevil'},
#   {'title': 'Peace Be Still', 'artist': 'The Emotions'},
#   {'title': "Don't Explain", 'artist': 'Billie Holiday'},
#   {'title': 'Hey, Who Really Cares?', 'artist': 'Linda Perhacs'},
#   {'title': 'Sunrise (A Long Time Ago)', 'artist': 'Devendra Banhart'},
#   {'title': "Zapata's Boots", 'artist': 'Tommy Guerrero'},
#   {'title': 'Who Is the Hunter', 'artist': 'Liars'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': 'GertSoul Guitar', 'artist': 'Gert Wilden & Orchestra'},
#   {'title': 'Passing By', 'artist': 'Zero 7'},
#   {'title': 'Moon Fever', 'artist': 'Air'},
#   {'title': 'Santa Maria da Feira', 'artist': 'Devendra Banhart'},
#   {'title': 'Somebody That I Used to Know', 'artist': 'Gotye'},
#   {'title': 'Brindo', 'artist': 'Devendra Banhart'},
#   {'title': 'Mad World (Alternate Version)', 'artist': 'Michael Andrews'},
#   {'title': 'Exit Music (for a Film)', 'artist': 'Radiohead'},
#   {'title': 'You and Whose Army?', 'artist': 'Radiohead'},
#   {'title': 'Come on Home to Me', 'artist': 'Lee Hazlewood'},
#   {'title': 'Six Feet of Chain', 'artist': 'Lee Hazlewood'},
#   {'title': 'Diamond Day', 'artist': 'Vashti Bunyan'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Muetersprach Official Video (uncut)', 'artist': 'Gleiszwei'},
#   {'title': 'Betruf', 'artist': 'Emil\xa0Dörig'},
#   {'title': 'Our Prayer / Gee', 'artist': 'Brian Wilson'},
#   {'title': 'The Railroad', 'artist': 'Lee Hazlewood'},
#   {'title': "You're My Thrill", 'artist': 'Peggy Lee'},
#   {'title': 'Sea, Sex and Sun  (Guido.reedit)', 'artist': 'Serge Gainsbourg'},
#   {'title': 'Melody', 'artist': 'Serge Gainsbourg'},
#   {'title': 'Treat Me Like That', 'artist': 'Blundetto'},
#   {'title': 'STATION-ID - Fro electronic', 'artist': 'Roland Widmer'},
#   {'title': 'User generated - english - ruhig', 'artist': 'Roland Widmer'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': '06.00 - 09.00 CROSSFADER - kurz', 'artist': 'Roland Widmer'},
#   {'title': 'Der Anfang', 'artist': 'Rocko Schamoni'},
#   {'title': 'Dirty Trip', 'artist': 'Air'},
#   {'title': 'Pause', 'artist': 'Art of Noise'},
#   {'title': 'Gayane Ballet Suite (Adagio)',
#    'artist': 'Aram Khatchatu...րամ Խաչատրյան)'},
#   {'title': 'Lotus Land Op. 47 No. 1', 'artist': 'Fritz Kreisler'},
#   {'title': 'Come Wander With Me', 'artist': 'Jeff Alexander'},
#   {'title': 'STATION-ID - Closer', 'artist': 'Roland Widmer'},
#   {'title': 'The Power to Believe I: A Cappella', 'artist': 'King Crimson'},
#   {'title': 'Mrs Henderson', 'artist': 'Funki Porcini'},
#   {'title': 'Caramel', 'artist': 'Suzanne Vega'},
#   {'title': 'Summertime', 'artist': 'Booker T. & The MG’s'},
#   {'title': 'Love and Happiness', 'artist': 'Al Green'},
#   {'title': "What A Diff'rence A Day Makes", 'artist': 'Dinah Washington'},
#   {'title': "I Can't Stand the Rain", 'artist': 'Ann Peebles'},
#   {'title': '06.00 - 09.00 CROSSFADER - lang', 'artist': 'Roland Widmer'},
#   {'title': 'Summertime', 'artist': 'The Residents'},
#   {'title': 'Superstar', 'artist': 'Sonic Youth'},
#   {'title': 'Camelblues', 'artist': 'Mndsgn'},
#   {'title': 'Loveschool Hamburg', 'artist': 'Rocko Schamoni'},
#   {'title': 'Electronic Poem', 'artist': 'Florian Schneider'},
#   {'title': 'Teardrops (take 17)', 'artist': 'Gene Vincent'},
#   {'title': 'Segue', 'artist': 'The New Power Generation'},
#   {'title': 'The Succubus', 'artist': 'Annette Peacock'},
#   {'title': "Let's Dance", 'artist': 'M. Ward'},
#   {'title': '06.00 - 09.00 CROSSFADER - kurz', 'artist': 'Roland Widmer'},
#   {'title': 'Im Bett', 'artist': 'Helge Schneider'},
#   {'title': 'A Word of Vice', 'artist': 'Funki Porcini'},
#   {'title': 'Moments in Love', 'artist': 'Art of Noise'},
#   {'title': 'The Militant (Mark Robinson Remix)', 'artist': 'Lambchop'},
#   {'title': 'Lapse', 'artist': 'Bill Callahan'},
#   {'title': 'User generated -... breathe and fly', 'artist': 'Roland Widmer'},
#   {'title': 'Majestix', 'artist': 'Helge Schneider'},
#   {'title': 'Astronomic Club', 'artist': 'Air'},
#   {'title': 'COLLAGE - 10er Reihe 45s', 'artist': 'Roland Widmer'},
#   {'title': 'STATION-ID - 5s Beep', 'artist': 'Roland Widmer'},
#   {'title': 'Soft', 'artist': 'Lemon Jelly'},
#   {'title': 'I’m Not in Love', 'artist': '10cc'},
#   {'title': 'The Rip', 'artist': 'Portishead'},
#   {'title': 'Chinese Translation', 'artist': 'M. Ward'},
#   {'title': 'Forecast', 'artist': 'R. Stevie Moore'},
#   {'title': 'Swing Low, Sweet Cadillac', 'artist': 'Dizzy Gillespie'},
#   {'title': 'Hold On', 'artist': 'The Bandana Splits'},
#   {'title': '06.00 - 09.00 CROSSFADER - lang', 'artist': 'Roland Widmer'},
#   {'title': 'Early in the Morning', 'artist': 'Harry Nilsson'},
#   {'title': "Didn't I", 'artist': 'Darondo'},
#   {'title': 'Our Day Will Come', 'artist': 'The Heptones'},
#   {'title': 'Fu Man Chu', 'artist': 'Desmond Dekker'},
#   {'title': 'Carioca', 'artist': 'Fred Astaire'},
#   {'title': 'Mister Echo (Monsieur Écho)', 'artist': 'Patrice et Mario'},
#   {'title': 'STATION-ID - Andavoicepur', 'artist': 'Roland Widmer'},
#   {'title': 'Don’t Cry Baby', 'artist': 'Madeleine Peyroux'},
#   {'title': 'Paloma Negra', 'artist': 'Chavela Vargas'},
#   {'title': 'That Naughty Waltz', 'artist': 'April Stevens'},
#   {'title': 'Moritat (A Theme...ee Penny Opera”)',
#    'artist': 'The Dick Hyman Trio'},
#   {'title': 'Eine Liebelei so nebenbei', 'artist': 'Lilian\xa0Harvey'},
#   {'title': 'STATION-ID - Whisper', 'artist': 'Roland Widmer'},
#   {'title': 'Majestix', 'artist': 'Helge Schneider'},
#   {'title': 'Flash Forward', 'artist': 'Serge Gainsbourg'},
#   {'title': '06.00 - 09.00 CROSSFADER - lang', 'artist': 'Roland Widmer'},
#   {'title': 'Feature, Part I (skit)', 'artist': 'Gleiszwei'},
#   {'title': 'U Ass Bank', 'artist': 'Lyrics Born'},
#   {'title': 'I Get a Kick Out...Orchestra Remix)',
#    'artist': 'Ella Fitzgerald'},
#   {'title': 'Knock On Wood', 'artist': 'Harpers Bizarre'},
#   {'title': 'If You Leave Me Now', 'artist': 'Chicago'},
#   {'title': 'Dream a Little Dream of Me', 'artist': 'The Mamas & the Papas'},
#   {'title': "You're Not Alone", 'artist': 'Jamie Woon'},
#   {'title': 'STATION-ID - Andavoicepur', 'artist': 'Roland Widmer'}]}

# %%
playlist['series']
# Out:
# 'Crossfader'

# %%
import utils
f"openbroadcast-{''.join(playlist['series'].split())}_{utils.timestamp()}.json"
# Out:
# 'openbroadcast-Crossfader_2020-04-23-19-57-45.json'

# %%
import json
import os
folder = 'data'
filename = f"openbroadcast-{''.join(playlist['series'].split())}_{utils.timestamp()}.json"
if not os.path.exists(folder):
    os.mkdir(folder)
with open(os.path.join(folder, filename), 'w', encoding='utf-8') as f:
    json.dump(playlist, f, ensure_ascii=False, indent=4)
