# %%
import matplotlib.pyplot as plt
import pandas as pd

import spotify
import utils

sp = spotify.login(scope='playlist-modify-private playlist-read-private')

# %%
user = sp.current_user()
username = user['id']
displayName = user['display_name']
displayName
# Out:
# 'Mehmet Birgi'

# %%
# get all my playlists 
response = sp.current_user_playlists()
all_playlists = response['items']
while response['next']:
    response = sp.next(response)
    all_playlists.extend(response['items'])
len(all_playlists)
# Out:
# 100

# %%
playlists = [{'id': pl['id'], 'name': pl['name'], 'desc': pl['description'], 'tracks': pl['tracks']['total']} for pl in all_playlists]

# %%
playlists_df = pd.DataFrame(playlists)
pd.set_option('display.max_rows', 200)
playlists_df
# Out:
#                         id                                          name  \
# 0   5mPQXXKMhVVPjMACWiPCcL                                Sounds of NOLA
# 1   29Nf3k71zmrxQKKGpgxwvG                                      Trip Hop
# 2   73kIi815YPv2G2l5fVllhD                              RnB, Funk & Soul
# 3   3BlDHipny169hRxNzk3Y2H                                       Ballads
# 4   3v9ftMWnKH5gou828qie9N                                         Disco
# 5   7taG2mm7i5ng9FTSYGXXgG                                        Lounge
# 6   3x9tqBoPyVaxk7bL4HGs9O                                      Pop/Rock
# 7   7ttRo7MjtCH0WSP2PrGAWD                                   Jazz/Fusion
# 8   7wHVkQaQ45X055sUeU5Thx                           Straight Ahead Jazz
# 9   6u5RL72VpPaJfeLksVLE2Q                                   Mellow Jazz
# 10  6MBIJnE6uom3iH5wzglrEK                                    Vocal Jazz
# 11  01PEgqXn5ZhC8z9a7HpVmG                                   Groovy Jazz
# 12  2AmGjZtnEsGjHY4btuyVtE                                     Laid Back
# 13  4eo9J2YJt44sFeiBSqKlAh                       Discover Weekly Archive
# 14  7JYdgqlBBhiCqjpx2pVKwf                                        Reggae
# 15  30ii4iPamUUUfIeq9AtoOF                                     Check Out
# 16  0vay9gW8AcsmEycNCh8pnz                                  Groovy Stuff
# 17  2MzQi9D9OtFuUsuOS8lwtS                                   Power Songs
# 18  2xt6hsdltb6Fx6ynapb2nq                                  Classic Rock
# 19  5cMOFVhGnVoAtPLdOBi2RO                                 Classic Blues
# 20  4sTTpg22IKCmCtlq7OskCA          Öbür Dünya - Açık Radyo - Ahmet Uluğ
# 21  2YMU8rioLryuhi4QhtXIAy                                  Eclectic Mix
# 22  3PZfQ2NkbDDTEFjjnNMqmZ            BPM 110 - 115 (Spotify Categories)
# 23  1pK8kJS0ENpKNUhdOhMWM2            BPM 115 - 120 (Spotify Categories)
# 24  4whWFX3KEKamJeTsrZZcTx            BPM 120 - 125 (Spotify Categories)
# 25  7iC0X4dTDasxaN59reQ6ll            BPM 125 - 130 (Spotify Categories)
# 26  2pa1jvBaVYoGLr4FJ5tnnL            BPM 130 - 135 (Spotify Categories)
# 27  0i55HUDwEB2uvxzO2p9pIR            BPM 135 - 140 (Spotify Categories)
# 28  417vyO9ziAl0JDYF9HHn8C                      BPM 110 - 115 All Tracks
# 16                Groovy Funk, Soul and R&amp;B stuff     371
# 17                               Uplifting evergreens     588
# 18                                                          3
# 19                                                          8
# 20  Tracks from Ahmet Uluğ&#x27;s program Öbür Dün...       8
# 21         Big playlist for shuffling, diverse genres    7101
# 22  Categories: [&#x27;edm_dance&#x27;, &#x27;rock...     125
# 23  Categories: [&#x27;edm_dance&#x27;, &#x27;rock...     176
# 24  Categories: [&#x27;edm_dance&#x27;, &#x27;rock...     209
# 25  Categories: [&#x27;edm_dance&#x27;, &#x27;rock...     175
# 26  Categories: [&#x27;edm_dance&#x27;, &#x27;rock...      82
# 27  Categories: [&#x27;edm_dance&#x27;, &#x27;rock...      45
# 28                                                        305
# 29                                                        320
# 30                                                        358
# 31                                                        396
# 32                                                        216
# 33                                                        128
# 34   Tracks from my iTunes library as of 2019, part 1    2744
# 35   Tracks from my iTunes library as of 2019, part 2    4897
# 36   Tracks from my iTunes library as of 2019, part 3     825
# 37   Tracks from my iTunes library as of 2019, part 4    6447
# 38         Trip-Hop song highlights from allmusic.com      39
# 39         Clubjazz song highlights from allmusic.com      36
# 40  The 3 most popular tracks for Clubjazz artist ...      36
# 41      Funky Beats song highlights from allmusic.com      34
# 42         Downbeat song highlights from allmusic.com      37
# 43          Dubstep song highlights from allmusic.com      43
# 44       Jazz-House song highlights from allmusic.com      31
# 45        Dancehall song highlights from allmusic.com      36
# 46            Ragga song highlights from allmusic.com      45
# 47             Soca song highlights from allmusic.com      27
# 48              Dub song highlights from allmusic.com      31
# 49      Lovers Rock song highlights from allmusic.com      40
# 50     Roots Reggae song highlights from allmusic.com      44
# 51            Disco song highlights from allmusic.com      33
# 52  Deep Funk Revival song highlights from allmusi...      42
# 53        Deep Funk song highlights from allmusic.com      36
# 54                                                        550
# 55                                                         32
# 56                                                         68
# 57                                                        139
# 58                                                        500
# 59                                                        265
# 60                                                        152
# 61                                                         88
# 62                                                        570
# 63                                                        461
# 64                                                       6892
# 65                                                        252
# 66  Some of the music release by the jazz re:fresh...     136
# 67  our man MC BLUE MATTER <a href="https://www.in...      28
# 68  New music from our roster and the artists we l...      92
# 69                                                         13
# 70                                                        115
# 71                                                        207
# 72                                                        162
# 73                                                        174
# 74  My favorite easy listening tracks made in this...    1155
# 75          My favorite Hard Bop and Cool Jazz albums     417
# 76                                                         95
# 77                       Old and new, mellow and wild      94
# 78                                                        633
# 79                       Jazzy stuff with fat grooves     155
# 80                                                          2
# 81                                                          1
# 82      No screaming guitars and howling wolves here!      34
# 83  Most of the songs that appeared on the great f...      78
# 84                                                         52
# 85                                                          4
# 86                                                        749
# 87                                                         27
# 88                                                         37
# 89                                                        232
# 90                                                         18
# 91  Your weekly mixtape of fresh music. Enjoy new ...      30
# 92                                                        534
# 93                                                        126
# 94                                                         90
# 95                                                        100
# 96                                                        123
# 97                                                         17
# 98                                                         20
# 99                                                        702

# %%
# jazzy mix
pl_selection = [
    '5mPQXXKMhVVPjMACWiPCcL',
    '73kIi815YPv2G2l5fVllhD',
    '3BlDHipny169hRxNzk3Y2H',
    '7ttRo7MjtCH0WSP2PrGAWD',
    '7wHVkQaQ45X055sUeU5Thx',
    '6u5RL72VpPaJfeLksVLE2Q',
    '6MBIJnE6uom3iH5wzglrEK',
    '01PEgqXn5ZhC8z9a7HpVmG',
    '6llGZ072CW6nCfZnP4IRpI',
    '31tFGldLHHeWvitXFG721v',
    '08CVuk5TKfBivxwWz0zu1X',
    '6yCyQLKLPHmNAM1qfXxaT2',
    '5JxWyerhVliarR0JEhV7Bh',
    '77523QiGKT14yvmZM4bJl9',
    '1npiimUFPnfOMfFKrwyc01',
    '03ackcJZFc4w9AkYeki1uw',
    '1FUKz6E2K5ldoAd4wbG8Ew'
]
tracks = spotify.get_tracks_in_playlists(sp, pl_selection)
track_ids = set([track['track']['id'] for track in tracks])
print(str(len(track_ids)) + " tracks")
playlist_id, is_new = spotify.get_playlist_by_name(sp, "Jazzy Mix", create_if_none=True)
if is_new:
    print("created playlist: " + playlist_id)
else:
    print("found playlist: " + playlist_id)
spotify.add_tracks(sp, playlist_id, track_ids)
sp.playlist_change_details(playlist_id, description="Big playlist for shuffling jazzy tunes")
print("done")
# Out:
# 9206 tracks
# found playlist: 35ZcAr7aUiNxfLKgVrk0Ii
# done

# %%
# eclectic mix
pl_selection = [
    '5mPQXXKMhVVPjMACWiPCcL',
    '29Nf3k71zmrxQKKGpgxwvG',
    '73kIi815YPv2G2l5fVllhD',
    '3x9tqBoPyVaxk7bL4HGs9O',
    '2AmGjZtnEsGjHY4btuyVtE',
    '7JYdgqlBBhiCqjpx2pVKwf',
    '2MzQi9D9OtFuUsuOS8lwtS',
    '4sTTpg22IKCmCtlq7OskCA',
    '7xagmfN234GMksUQA6jEBj',
    '2uBiRZO1bom5xbFD8Dwye4',
    '5vme2VCH9rHNsAXjmvDG5D',
    '3clgFwEnConAeWJ4rVGwua',
    '2RSRahV4MyEL0IsBXT3UCe',
    '5dZZL80qyI19sIdRMe9g8U',
    '3cqLAJrcSpZJcarmbHS6Lu',
    '2IZoEQC2TAzlsM6JjAVgeS',
    '0pCTEsu559LSbRY7lrMt8z',
    '2J7C570IoHMn1zccjQMF2Q',
    '31ncBxcoGHB9lTbAEly5xR',
    '566s1zzyRtF4bzv9JfpnVY'
]
tracks = spotify.get_tracks_in_playlists(sp, pl_selection)
track_ids = set([track['track']['id'] for track in tracks])
print(str(len(track_ids)) + " tracks")

playlist_id, is_new = spotify.get_playlist_by_name(sp, "Eclectic Mix", create_if_none=True)
if is_new:
    print("created playlist: " + playlist_id)
else:
    print("found playlist: " + playlist_id)
spotify.add_tracks(sp, playlist_id, track_ids)
sp.playlist_change_details(playlist_id, description="Big playlist for shuffling, diverse genres")
print("done")
# Out:
# 7737 tracks
# found playlist: 2YMU8rioLryuhi4QhtXIAy
# done
